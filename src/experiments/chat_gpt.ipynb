# %%
import os
import openai
import json
import pandas as pd
from datetime import datetime
from tqdm.notebook import tqdm
import time
from dotenv import load_dotenv
import helper as analytics

# %%
# Load OPENAI_API_KEY from .env file
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI(api_key=os.getenv("CHATGPTKEY"))

# %%
model_id = "gpt-4o-mini"
BASE_PATH = f"../../results/{model_id}"

# %%
def generate_explanations(product_1:str, product_2:str, label:str):
    completion = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "user", "content": f"""
        Do the two entity descriptions refer to the same real-world entity?
        Entity 1: {product_1}
        Entity 2: {product_2}

        The correct answer is {label}.

        Please provide an explanation for this answer in a structured format, listing the attributes that you compared for reaching this answer. Each attribute should be accompanied by the attribute values and a score between -1 and 1 that shows the importance of the attribute for the decision. If the attribute influenced the decision towards non-match the importance score should be negative. If the attribute pointed towards a match, the importance score should be positive. Also provide a similarity score for the attribute values. If an attribute only occurs in one item, specify the value of that attribute for the other item as "missing". An example output is the following:

        attribute=brand|||importance=0.05|||values=Logitech###Logitech|||similarity=1.00
        attribute=model|||importance=-0.95|||values=MX G500###MX Master 3S|||similarity=0.20
        attribute=color|||importance=0.00|||values=missing###Graphite|||similarity=0.00
        
        Here is a complete example:
        Do the two product descriptions refer to the same real-world product? Entity 1: 'WD 4TB Black My Passport Portable External Hard Drive - USB 3.0 - WDBYFT0040BBK-WESN'. Entity 2: 'Dysk WD My Passport 1TB USB 3.0 black'.
        "No. 
        attribute=brand|||importance=0.05|||values=Western Digital###Western Digital|||similarity=1.00
        attribute=model|||importance=0.95|||values=My Passport###My Passport|||similarity=1.00
        attribute=storage capacity|||importance=0.9|||values=4TB###1TB|||similarity=0.25
        attribute=color|||importance=0.1|||values=Black###Black|||similarity=1.00
        attribute=USB version|||importance=0.05|||values=USB 3.0###USB 3.0|||similarity=1.00
        
        Do not provide a explanation in a different format. The explanation should be in the format described above. Only provide the answer and explanation dont repeat the question.
        
        """}
    ],
        max_tokens=300,
        temperature=0
    )
    return {
        "answer": completion.choices[0].message.content,
        "total_tokens": completion.usage.total_tokens,
        "prompt_tokens": completion.usage.prompt_tokens,
        "completion_tokens": completion.usage.completion_tokens
    }
    
print(generate_explanations("WD 4TB Black My Passport Portable External Hard Drive - USB 3.0 - WDBYFT0040BBK-WESN", "Dysk WD My Passport 1TB USB 3.0 black", "No"))
# Out:
# {'answer': 'No. \nattribute=brand|||importance=0.05|||values=WD###WD|||similarity=1.00\nattribute=model|||importance=0.95|||values=My Passport###My Passport|||similarity=1.00\nattribute=storage capacity|||importance=0.9|||values=4TB###1TB|||similarity=0.25\nattribute=color|||importance=0.1|||values=Black###Black|||similarity=1.00\nattribute=USB version|||importance=0.05|||values=USB 3.0###USB 3.0|||similarity=1.00', 'total_tokens': 665, 'prompt_tokens': 536, 'completion_tokens': 129}

# %%
small_df = pd.read_pickle(f"../../data/wdc/preprocessed_wdcproducts80cc20rnd000un_train_small.pkl.gz", compression="gzip")
# Iterate over the small dataset and generate explanations

for index, row in tqdm(small_df.iterrows(), total=small_df.shape[0]):
    product_1 = row["title_left"]
    product_2 = row["title_right"]
    label = row["label"]
    explanation = generate_explanations(product_1, product_2, label)
    small_df.loc[index, "explanation"] = explanation["answer"]
    small_df.loc[index, "total_tokens"] = explanation["total_tokens"]
    small_df.loc[index, "prompt_tokens"] = explanation["prompt_tokens"]
    small_df.loc[index, "completion_tokens"] = explanation["completion_tokens"]

small_df.to_pickle(f"../../data/wdc/preprocessed_wdcproducts80cc20rnd000un_train_small_explanations_40.pkl.gz", compression="gzip")
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]

# %%
small_df.to_pickle(f"../../data/wdc/preprocessed_wdcproducts80cc20rnd000un_train_small_explanations_40_mini.pkl.gz", compression="gzip")

# %%
def clean_response(response):
    if "yes" in response.lower():
        return 1
    else:
        return 0

# %%
def insert_product_descriptions(prompt_template: str, product1: str, product2: str):
    # Replace placeholder texts with actual product descriptions
    prompt = prompt_template.replace("'Entity 1'", product1).replace("'Entity 2'", product2)
    return prompt

# %%
def generate_answer(prompt: str, model:str = "gpt-3.5-turbo-0125", max_new_tokens=5):  
    completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "user", "content": prompt}
    ],
        max_tokens=max_new_tokens,
        temperature=0
    )
    return completion.choices[0].message.content, completion.usage.total_tokens, completion.usage.prompt_tokens, completion.usage.completion_tokens

# %%
generate_answer("Hello world", "gpt-4o-mini")
# Out:
# ('Hello! How can I', 14, 9, 5)

# %% [markdown]
# # Connect to ChatGpt Api

# %% [markdown]
# ## Start testing

# %%
result_rows = []

datasets = [{"dataset_name": "wdc", "dataset_path": "../../data/wdc/preprocessed_wdcproducts80cc20rnd000unsampled250_2_gs_testset_ralph.pkl"}, {"dataset_name": "abt-buy", "dataset_path": "../../data/abt-buy/abt-buy-sampled_gs.pkl"}, {"dataset_name": "amazon-google", "dataset_path": "../../data/amazon-google/amazon-google-sampled_gs.pkl"}]

for dataset in datasets:
    # Load the dataset
    df = pd.read_pickle(dataset["dataset_path"])

    # Load all prompts we want to test
    with open('../../prompts/domain_promts.json', 'r') as file:
        prompts = json.load(file)

    result_rows = []

    for task in prompts:
        title = task['title']
        prompt_template = task['prompt']
        print(f"Processing dataset: {dataset['dataset_name']} \n Processing task:  {title}")

        for index, row in df.iterrows():
            product1, product2, label = row['title_left'], row['title_right'], row.get('label') 
            message = insert_product_descriptions(prompt_template, product1, product2)
            
            response = ""
            error = ""

            
            response, total_tokens, prompt_tokens, completion_tokens = generate_answer(message, model_id, 5)
            # Prepare a result dictionary combining task info with the original row data
            result_row = {
                'task': title,
                'chatbot_question': message,
                'chatbot_response_raw': response if response else error,
                'chatbot_response_clean': clean_response(response),
                'total_tokens': total_tokens,
                'prompt_tokens': prompt_tokens,
                'completion_tokens': completion_tokens
            }
            
            # Add original dataframe row data
            for col in df.columns:
                result_row[col] = row[col]

            # Append this combined result row to the list
            result_rows.append(result_row)

            if index % 250 == 0:
                print(f"Processed {index} out of {len(df)} queries")


    all_columns = ['task', 'chatbot_question', 'chatbot_response_raw', 'chatbot_response_clean'] + list(df.columns)

    # Convert the list of dictionaries to a DataFrame
    results_df = pd.DataFrame(result_rows, columns=all_columns)

    # get the current date and time
    now = datetime.now()

    directory = f"{BASE_PATH}/{dataset['dataset_name']}"
    if not os.path.exists(directory):
        os.makedirs(directory)

    # save the dataframe as a json file
    results_df.to_json(f"{BASE_PATH}/{dataset['dataset_name']}/{now.strftime('%Y-%m-%d-%H-%M-%S')}.json")
# Out:
# Processing dataset: wdc
#  Processing task:  domain-complex-free (Product)
# Processed 0 out of 1239 queries
# Processed 250 out of 1239 queries
# Processed 500 out of 1239 queries
# Processed 750 out of 1239 queries
# Processed 1000 out of 1239 queries
# Processing dataset: wdc
#  Processing task:  domain-simple-free (Product)
# Processed 0 out of 1239 queries
# Processed 250 out of 1239 queries
# Processed 500 out of 1239 queries
# Processed 750 out of 1239 queries
# Processed 1000 out of 1239 queries
# Processing dataset: wdc
#  Processing task:  domain-complex-force (Product)
# Processed 0 out of 1239 queries
# Processed 250 out of 1239 queries
# Processed 500 out of 1239 queries
# Processed 750 out of 1239 queries
# Processed 1000 out of 1239 queries
# Processing dataset: wdc
#  Processing task:  domain-simple-force (Product)
# Processed 0 out of 1239 queries
# Processed 250 out of 1239 queries
# Processed 500 out of 1239 queries
# Processed 750 out of 1239 queries
# Processed 1000 out of 1239 queries
# Processing dataset: abt-buy
#  Processing task:  domain-complex-free (Product)
# Processed 0 out of 1206 queries
# Processed 250 out of 1206 queries
# Processed 500 out of 1206 queries
# Processed 750 out of 1206 queries
# Processed 1000 out of 1206 queries
# Processing dataset: abt-buy
#  Processing task:  domain-simple-free (Product)
# Processed 0 out of 1206 queries
# Processed 250 out of 1206 queries
# Processed 500 out of 1206 queries
# Processed 750 out of 1206 queries
# Processed 1000 out of 1206 queries
# Processing dataset: abt-buy
#  Processing task:  domain-complex-force (Product)
# Processed 0 out of 1206 queries
# Processed 250 out of 1206 queries
# Processed 500 out of 1206 queries
# Processed 750 out of 1206 queries
# Processed 1000 out of 1206 queries
# Processing dataset: abt-buy
#  Processing task:  domain-simple-force (Product)
# Processed 0 out of 1206 queries
# Processed 250 out of 1206 queries
# Processed 500 out of 1206 queries
# Processed 750 out of 1206 queries
# Processed 1000 out of 1206 queries
# Processing dataset: amazon-google
#  Processing task:  domain-complex-free (Product)
# Processed 0 out of 1234 queries
# Processed 250 out of 1234 queries
# Processed 500 out of 1234 queries
# Processed 750 out of 1234 queries
# Processed 1000 out of 1234 queries
# Processing dataset: amazon-google
#  Processing task:  domain-simple-free (Product)
# Processed 0 out of 1234 queries

# %%
result_paths = analytics.get_all_files_in_directory(f"{BASE_PATH}/")
stats = analytics.calculate_fine_tuned_stats(result_paths, model_id)

# Initialize an empty dataframe to collect all rows
combined_df = pd.DataFrame()

# Iterate through the data and concatenate
for entry in stats:
    stats_df = entry['stats']
    stats_df['model'] = entry['model']
    stats_df['benchmark'] = entry['benchmark']
    stats_df['file_path'] = entry['file_path']
    combined_df = pd.concat([combined_df, stats_df], ignore_index=True)

# Reordering columns so that 'model' and 'benchmark' are the first two columns
combined_df = combined_df[['model', 'benchmark', 'Task', 'Accuracy', 'F1 Score', 'Precision', 'Recall', 'Num -1 Responses', 'file_path']]

combined_df.to_csv(f"{BASE_PATH}/results/stats.csv")

# %%
combined_df
# Out:
#                                                 model      benchmark  \
# 0   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...  amazon-google
# 1   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...  amazon-google
# 2   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...  amazon-google
# 3   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...  amazon-google
# 4   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...            wdc
# 5   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...            wdc
# 6   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...            wdc
# 7   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...            wdc
# 8   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...        abt-buy
# 9   ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...        abt-buy
# 10  ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...        abt-buy
# 11  ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4o...        abt-buy
#
#                               Task  Accuracy  F1 Score  Precision    Recall  \
# 0    domain-complex-free (Product)  0.841977  0.701378   0.546539  0.978632
# 1     domain-simple-free (Product)  0.851702  0.712716   0.563275  0.970085
# 2   domain-complex-force (Product)  0.851702  0.713615   0.562963  0.974359
# 3    domain-simple-force (Product)  0.857374  0.720635   0.573232  0.970085
# 4    domain-complex-free (Product)  0.951574  0.887640   0.834507  0.948000
# 5     domain-simple-free (Product)  0.955609  0.896811   0.844523  0.956000
# 6   domain-complex-force (Product)  0.954802  0.894340   0.846429  0.948000
# 7    domain-simple-force (Product)  0.955609  0.895636   0.851986  0.944000
# 8    domain-complex-free (Product)  0.970149  0.918552   0.860169  0.985437
# 9     domain-simple-free (Product)  0.975124  0.931193   0.882609  0.985437
# 10  domain-complex-force (Product)  0.974295  0.929062   0.878788  0.985437
# 11   domain-simple-force (Product)  0.977612  0.937644   0.894273  0.985437
#
#     Num -1 Responses                                          file_path
# 0                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 1                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 2                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 3                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 4                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 5                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 6                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 7                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 8                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 9                  0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 10                 0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...
# 11                 0  ../../results/ft:gpt-4o-mini-2024-07-18:wbsg-u...

# %%
# open our test dataframe from the csv
df = pd.read_pickle('../data/wdc/preprocessed_wdcproducts80cc20rnd000unsampled250_2_gs_testset_ralph.pkl')
df.head(2)
# Out:
#     id_left brand_left                                     title_left  \
# 0  67017951        NaN          Ubiquiti UniFi Protect Video Security
# 1  41364196        NaN  Kšiltovka New Era Clean Trucker Chicago Bulls
#
#                                     description_left price_left  \
# 0  Ubiquiti's UniFi Protect offers all the flexib...        NaN
# 1                                                NaN        658
#
#   priceCurrency_left  specTableContent_left  cluster_id_left  id_right  \
# 0                NaN                    NaN          1649038   5303451
# 1                CZK                    NaN         46857262  29165749
#
#   brand_right                                      title_right  \
# 0         NaN  Ubiquiti UniFi Video G3 Infrared Range Extender
# 1         NaN    Kšiltovka New Era New York Yankees MLB 9Fifty
#
#                                    description_right price_right  \
# 0  The IR Range Extender is a 'Plug and Play' acc...       70.80
# 1                                                NaN         810
#
#   priceCurrency_right  specTableContent_right  cluster_id_right  \
# 0                 GBP                     NaN            711907
# 1                 CZK                     NaN          76491423
#
#              pair_id  label  is_hard_negative
# 0   67017951#5303451      0              True
# 1  41364196#29165749      0              True

# %%
base_path = "../results/gpt-4o-mini"
# Load all prompts we want to test
with open('../prompts/domain_promts.json', 'r') as file:
    prompts = json.load(file)

result_rows = []
times = []

for task in prompts:
    title = task['title']
    prompt_template = task['prompt']
    print(f"Processing task:  {title}")

    for index, row in df.iterrows():
        start_time = time.time()
        product1, product2, label = row['title_left'], row['title_right'], row.get('label') 
        message = insert_product_descriptions(prompt_template, product1, product2)
        
        response = ""
        error = ""

        
        response, total_tokens, prompt_tokens, completion_tokens = generate_answer(message, "ft:gpt-4o-mini-2024-07-18:wbsg-uni-mannheim:4ominifirst:9oUSMtcj", 10)
        end_time = time.time()
        times.append(end_time - start_time)
        # Prepare a result dictionary combining task info with the original row data
        result_row = {
            'task': title,
            'chatbot_question': message,
            'chatbot_response_raw': response if response else error,
            'chatbot_response_clean': clean_response(response),
            'total_tokens': total_tokens,
            'prompt_tokens': prompt_tokens,
            'completion_tokens': completion_tokens
        }
        
        # Add original dataframe row data
        for col in df.columns:
            result_row[col] = row[col]

        # Append this combined result row to the list
        result_rows.append(result_row)

        if index % 50 == 0:
            print(f"Processed {index} out of {len(df)} queries")


    all_columns = ['task', 'chatbot_question', 'chatbot_response_raw', 'chatbot_response_clean',"prompt_tokens", "completion_tokens", "total_tokens"] + list(df.columns)

    # Convert the list of dictionaries to a DataFrame
    results_df = pd.DataFrame(result_rows, columns=all_columns)

    # get the current date and time
    now = datetime.now()

    directory = f"{base_path}"
    if not os.path.exists(directory):
        os.makedirs(directory)

    # save the dataframe as a json file
    results_df.to_json(f"{base_path}/{now.strftime('%Y-%m-%d-%H-%M-%S')}_wdc_testset.json")
# Out:
# Processing task:  domain-complex-free (Product)
# Processed 0 out of 1239 queries
# Processed 50 out of 1239 queries
# Processed 100 out of 1239 queries
# Processed 150 out of 1239 queries
# Processed 200 out of 1239 queries
# Processed 250 out of 1239 queries
# Processed 300 out of 1239 queries
# Processed 350 out of 1239 queries
# Processed 400 out of 1239 queries
# Processed 450 out of 1239 queries
# Processed 500 out of 1239 queries
# Processed 550 out of 1239 queries
# Processed 600 out of 1239 queries
# Processed 650 out of 1239 queries
# Processed 700 out of 1239 queries
# Processed 750 out of 1239 queries
# Processed 800 out of 1239 queries
# Processed 850 out of 1239 queries
# Processed 900 out of 1239 queries
# Processed 950 out of 1239 queries
# Processed 1000 out of 1239 queries

# %%
all_columns = ['task', 'chatbot_question', 'chatbot_response_raw', 'chatbot_response_clean',"prompt_tokens", "completion_tokens", "total_tokens"] + list(df.columns)

# Convert the list of dictionaries to a DataFrame
results_df = pd.DataFrame(result_rows, columns=all_columns)

# get the current date and time
now = datetime.now()

directory = f"{base_path}"
if not os.path.exists(directory):
    os.makedirs(directory)

# save the dataframe as a json file
results_df.to_json(f"{base_path}/{now.strftime('%Y-%m-%d-%H-%M-%S')}_wdc_testset.json")

# %%
result_rows
# Out:
# [{'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Ubiquiti UniFi Protect Video Security. Entity 2: Ubiquiti UniFi Video G3 Infrared Range Extender.',
#   'chatbot_response_raw': 'No, the two product descriptions refer to different products',
#   'chatbot_response_clean': 0,
#   'total_tokens': 61,
#   'prompt_tokens': 51,
#   'completion_tokens': 10,
#   'id_left': 67017951,
#   'brand_left': nan,
#   'title_left': 'Ubiquiti UniFi Protect Video Security',
#   'description_left': "Ubiquiti's UniFi Protect offers all the flexibility one would need for their home security needs. Here's our full review.",
#   'price_left': nan,
#   'priceCurrency_left': nan,
#   'specTableContent_left': nan,
#   'cluster_id_left': 1649038,
#   'id_right': 5303451,
#   'brand_right': nan,
#   'title_right': 'Ubiquiti UniFi Video G3 Infrared Range Extender',
#   'description_right': "The IR Range Extender is a 'Plug and Play' accessory designed to enhance and extend the night vision capabilities of the UVC-G3 camera.UVC-G3-LED Specification:-Enhances Night Vision RecordingsExtends IR Range up to 25m (82ft)Six High-Intensity Infrared LEDsPowered and Controlled by the UVC-G3...",
#   'price_right': '70.80',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 711907,
#   'pair_id': '67017951#5303451',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Kšiltovka New Era Clean Trucker Chicago Bulls. Entity 2: Kšiltovka New Era New York Yankees MLB 9Fifty.',
#   'chatbot_response_raw': 'No, the two product descriptions refer to different real',
#   'chatbot_response_clean': 0,
#   'total_tokens': 67,
#   'prompt_tokens': 57,
#   'completion_tokens': 10,
#   'id_left': 41364196,
#   'brand_left': nan,
#   'title_left': 'Kšiltovka New Era Clean Trucker Chicago Bulls',
#   'description_left': nan,
#   'price_left': '658',
#   'priceCurrency_left': 'CZK',
#   'specTableContent_left': nan,
#   'cluster_id_left': 46857262,
#   'id_right': 29165749,
#   'brand_right': nan,
#   'title_right': 'Kšiltovka New Era New York Yankees MLB 9Fifty',
#   'description_right': nan,
#   'price_right': '810',
#   'priceCurrency_right': 'CZK',
#   'specTableContent_right': nan,
#   'cluster_id_right': 76491423,
#   'pair_id': '41364196#29165749',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: DYMO D1 - Glossy tape - black on white - Roll (1.9cm x 7m) - 1 roll(s). Entity 2: DYMO 45017 D1 Tape 12mm x 7m sort p rd, S0720570.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 92,
#   'prompt_tokens': 82,
#   'completion_tokens': 10,
#   'id_left': 49744056,
#   'brand_left': nan,
#   'title_left': 'DYMO D1 - Glossy tape - black on white - Roll (1.9cm x 7m) - 1 roll(s)',
#   'description_left': 'Dymo 2000/5500 Tape 19mmx7m Black/White 45803.',
#   'price_left': '13.49',
#   'priceCurrency_left': 'GBP',
#   'specTableContent_left': nan,
#   'cluster_id_left': 103304,
#   'id_right': 66087579,
#   'brand_right': 'DYMO',
#   'title_right': 'DYMO 45017 D1 Tape 12mm x 7m sort p rd, S0720570',
#   'description_right': 'Originalt DYMO 45017 D1-tape SORT/RD Passer til: DYMO Labelpoint 120P / 150 / 200 / 210D / 250 / 300 / 350 DYMO Labelmanager 150 / 160 / 200 / 210D / 220P / 260P / 280 / 300 / 350 / 360D / 400 / 420P / 450 / 450D DYMO Labelmanager PC / PCII / PNP DYMO Labelmanager Mobile DYMO Labelwriter 400 Duo / 450 Duo Bredde 12mm Lngde 7meter.',
#   'price_right': '139.00',
#   'priceCurrency_right': 'DKK',
#   'specTableContent_right': nan,
#   'cluster_id_right': 48435,
#   'pair_id': '49744056#66087579',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: SAMSUNG T7 Touch Black 2TB Portable SSD with Fingerprint ID. Entity 2: T7 Portable SSD - 2TB Indigo Blue.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 67,
#   'prompt_tokens': 57,
#   'completion_tokens': 10,
#   'id_left': 63587638,
#   'brand_left': 'Samsung',
#   'title_left': 'SAMSUNG T7 Touch Black 2TB Portable SSD with Fingerprint ID',
#   'description_left': '2TB Samsung T7 Touch MU-PC2T0K/WW, Portable External SSD, Fingerprint ID, USB 3.2 Gen2/Type-C,Bus Powered, Black',
#   'price_left': '365.99',
#   'priceCurrency_left': 'GBP',
#   'specTableContent_left': nan,
#   'cluster_id_left': 327893,
#   'id_right': 52588862,
#   'brand_right': nan,
#   'title_right': 'T7 Portable SSD - 2TB Indigo Blue',
#   'description_right': 'Light and pocket-sized, the Portable SSD T7 both delivers fast speeds and safeguards data for an easy way to store and transfer large files. Experience everyday high performance in your work and play with the T7.',
#   'price_right': '639.99',
#   'priceCurrency_right': 'NZD',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1252792,
#   'pair_id': '63587638#52588862',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Kingston Canvas 128GB Micro SDXC C10 U1 V10 A1. Entity 2: Transcend SSD230S 128GB best price.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 67,
#   'prompt_tokens': 57,
#   'completion_tokens': 10,
#   'id_left': 25138178,
#   'brand_left': nan,
#   'title_left': 'Kingston Canvas 128GB Micro SDXC C10 U1 V10 A1',
#   'description_left': nan,
#   'price_left': '39.95',
#   'priceCurrency_left': 'USD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 27477,
#   'id_right': 45664586,
#   'brand_right': nan,
#   'title_right': 'Transcend SSD230S 128GB best price',
#   'description_right': 'Transcend 128GB 2.5\\" SSD230S SATA3 3D NAND Flash TLC, read-write: up to 560MBs, 520MBs, Aluminum case Price: 22.08. Best price from OmniChannel. Convenient payment by bank transfer or delivery',
#   'price_right': '2.208E1',
#   'priceCurrency_right': 'eur',
#   'specTableContent_right': nan,
#   'cluster_id_right': 715391,
#   'pair_id': '25138178#45664586',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Jabra BIZ 2400 II DQ Duo NC WB Corded Headset. Entity 2: Jabra Biz 2300 USB Duo Headset.',
#   'chatbot_response_raw': 'No, the two product descriptions refer to different products',
#   'chatbot_response_clean': 0,
#   'total_tokens': 67,
#   'prompt_tokens': 57,
#   'completion_tokens': 10,
#   'id_left': 56902092,
#   'brand_left': 'Jabra',
#   'title_left': 'Jabra BIZ 2400 II DQ Duo NC WB Corded Headset',
#   'description_left': nan,
#   'price_left': '209',
#   'priceCurrency_left': 'USD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 472648,
#   'id_right': 5578260,
#   'brand_right': nan,
#   'title_right': 'Jabra Biz 2300 USB Duo Headset',
#   'description_right': 'The Jabra Biz 2300 USB Duo is a dual ear noise cancelling headset designed for Unified Communication (UC) and Skype for Business (SFB) environments.Audio features include a Noise Cancelling Microphone to reduce background noise, wideband audio technology and DSP technology for better clarity.The Jabra Biz 2300 series is built to last, with a reinforced Kevlar cord and unbreakable boom arm the 2300 series can withstand any punishment a high performing contact centre can give.',
#   'price_right': '108.00',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 666306,
#   'pair_id': '56902092#5578260',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: AirPods 2 with Wireless Charging Case. Entity 2: PENDRIVE 128GB USB3.0 TIPO C KINGSTON DT MICRO DUO.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 70,
#   'prompt_tokens': 60,
#   'completion_tokens': 10,
#   'id_left': 28769706,
#   'brand_left': nan,
#   'title_left': 'AirPods 2 with Wireless Charging Case',
#   'description_left': 'Summary:- Designed by Apple- Automatically on, automatically connected- Easy setup for all your Apple devices6- Quick access to Siri by saying “Hey Siri” or setting up double-tap- Double-tap to play or skip forward- Charges quickly in the case- Case can be charged with a Lightning connector- Rich, high-quality audio and voice- Seamless switching between devicesMore magical than ever.The new AirPods deliver the wireless headphone experience, reimagined. Just pull them out of the charging case and they’re ready to use with your iPhone, Apple Watch, iPad, or Mac.After a simple one-tap setup, AirPods work like magic. They’re automatically on and always',
#   'price_left': '190.90',
#   'priceCurrency_left': 'EUR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1126552,
#   'id_right': 78600248,
#   'brand_right': nan,
#   'title_right': 'PENDRIVE 128GB USB3.0 TIPO C KINGSTON DT MICRO DUO',
#   'description_right': 'PENDRIVE 128GB USB3.0 TIPO C KINGSTON DT MICRO DUO Lectura 100Mbs / Escritura 15Mbs / USB(A)-USB(C) DTDUO3C/128GB',
#   'price_right': '30.18',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1085000,
#   'pair_id': '28769706#78600248',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: EPSON - Ink Cart/XL Yellow WF-8xxx. Entity 2: Epson C13T865140 WF-51xx/56xx Cartridge XXL Mono.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 71,
#   'prompt_tokens': 61,
#   'completion_tokens': 10,
#   'id_left': 28403450,
#   'brand_left': nan,
#   'title_left': 'EPSON - Ink Cart/XL Yellow WF-8xxx',
#   'description_left': 'EPSON Ink Cart/XL Yellow WF-8xxx (C13T755440) - Produkt: Blekk',
#   'price_left': '901.25',
#   'priceCurrency_left': 'NOK',
#   'specTableContent_left': nan,
#   'cluster_id_left': 2806654,
#   'id_right': 47959304,
#   'brand_right': nan,
#   'title_right': 'Epson C13T865140 WF-51xx/56xx Cartridge XXL Mono',
#   'description_right': nan,
#   'price_right': '549',
#   'priceCurrency_right': 'PLN',
#   'specTableContent_right': nan,
#   'cluster_id_right': 193507,
#   'pair_id': '28403450#47959304',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: APC SMART-UPS 1000VA 2U Uninterruptable Power Supply. Entity 2: APC Smart-UPS 1000VA LCD 230V SMT1000I - SMT1000I.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 79,
#   'prompt_tokens': 69,
#   'completion_tokens': 10,
#   'id_left': 62062623,
#   'brand_left': 'APC',
#   'title_left': 'APC SMART-UPS 1000VA 2U Uninterruptable Power Supply',
#   'description_left': '1000VA APC SMT1000RMI2UC UPS, 2U, LCD Screen, Battery Active/Low Alarm, 3 Hour Recharge Time',
#   'price_left': '647.99',
#   'priceCurrency_left': 'GBP',
#   'specTableContent_left': nan,
#   'cluster_id_left': 91557,
#   'id_right': 16111692,
#   'brand_right': 'APC by Schneider Electric',
#   'title_right': 'APC Smart-UPS 1000VA LCD 230V SMT1000I - SMT1000I',
#   'description_right': 'APC Smart-UPS 1000VA LCD 230V SMT1000I - SMT1000I - Single Phase - \ufeffSMT1000I Features APC Smart-UPS 1000VA LCD 230VIntelligent and efficient network power protection from entry level to scaleable runtime. Ideal UPS for servers, point-of-sale, routers, swi',
#   'price_right': '7150',
#   'priceCurrency_right': 'EGP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 2132160,
#   'pair_id': '62062623#16111692',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: GARMIN FENIX 5S Sapphire - Black with Black Band. Entity 2: Garmin fenix 5S Plus - Silver with black band.',
#   'chatbot_response_raw': 'No, the two product descriptions refer to different versions',
#   'chatbot_response_clean': 0,
#   'total_tokens': 66,
#   'prompt_tokens': 56,
#   'completion_tokens': 10,
#   'id_left': 45366053,
#   'brand_left': nan,
#   'title_left': 'GARMIN FENIX 5S Sapphire - Black with Black Band',
#   'description_left': "GARMIN FENIX 5S Sapphire - Black with Black Band Striking Design, Strong Performance...Athletes and adventurers come in all sizes. That's why the fenix 5 series offers multiple models that vary in size to fit every wrist and every workout. Each version offers a variety of stainless steel finishes, QuickFit watch band combinations and premium feature sets to give you the look, performance and lightweight comfort to match both your aesthetic and athletic interests. KEY FEATURES HR at the Wrist - Elevate wrist-based heart rate technology for HR without the chest strap. Chroma Display - bright, high-resolution, full-colour with LED backlighting.",
#   'price_left': '949',
#   'priceCurrency_left': 'AUD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1406172,
#   'id_right': 34146981,
#   'brand_right': nan,
#   'title_right': 'Garmin fenix 5S Plus - Silver with black band',
#   'description_right': nan,
#   'price_right': '4.5E2',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 23040,
#   'pair_id': '45366053#34146981',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Kingston 4GB DDR3 1866MHz HyperX Fury Black Series. Entity 2: GeForce® RTX 2080 SUPER™ OC, DUAL-RTX2080S-O8G-EVO, 1650 - 1860MHz, 8GB GDDR6, Graphics Card.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 98,
#   'prompt_tokens': 88,
#   'completion_tokens': 10,
#   'id_left': 31517280,
#   'brand_left': 'Kingston',
#   'title_left': 'Kingston 4GB DDR3 1866MHz HyperX Fury Black Series',
#   'description_left': 'DDR3, 4GB, 1866MHz, CL10',
#   'price_left': '8829.04',
#   'priceCurrency_left': 'HUF',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1877306,
#   'id_right': 43227294,
#   'brand_right': nan,
#   'title_right': 'GeForce® RTX 2080 SUPER™ OC, DUAL-RTX2080S-O8G-EVO, 1650 - 1860MHz, 8GB GDDR6, Graphics Card',
#   'description_right': 'The ASUS Dual GeForce® RTX 2080 SUPER™ EVO OC edition 8GB GDDR6 with two powerful Axial-tech fans for high refresh rate AAA gaming and VR',
#   'price_right': '805.51',
#   'priceCurrency_right': 'USD',
#   'specTableContent_right': nan,
#   'cluster_id_right': 3154731,
#   'pair_id': '31517280#43227294',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Kingston Canvas Select Plus 128GB Micro SD UHS-I (U1) Flash Card with Adapter. Entity 2: RAM Double U-Bolt Base with 2.25\\" Ball.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 73,
#   'prompt_tokens': 63,
#   'completion_tokens': 10,
#   'id_left': 25445188,
#   'brand_left': 'Kingston',
#   'title_left': 'Kingston Canvas Select Plus 128GB Micro SD UHS-I (U1) Flash Card with Adapter',
#   'description_left': nan,
#   'price_left': '35.99',
#   'priceCurrency_left': 'EUR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 27477,
#   'id_right': 14737778,
#   'brand_right': nan,
#   'title_right': 'RAM Double U-Bolt Base with 2.25\\" Ball',
#   'description_right': 'The RAM-D-235U by RAM Mounts consists of a stainless steel double u-bolt base connected to a 2.25\\" diameter ball. The double u-bolt base will accommdate rails from 0.75\\" to 1.25\\" in diameter.Material: Powder Coated Marine Grade AluminumBall Size: 2.25\\" Rubber Ball \\"D\\" Size',
#   'price_right': '$64.05',
#   'priceCurrency_right': 'AUD',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1571647,
#   'pair_id': '25445188#14737778',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Canon 10-18mm IS STM Lens. Entity 2: Canon EF-M 18-150mm f/3.5-6.3 IS STM Lens - Graphite.',
#   'chatbot_response_raw': 'No, the two product descriptions refer to different Canon',
#   'chatbot_response_clean': 0,
#   'total_tokens': 72,
#   'prompt_tokens': 62,
#   'completion_tokens': 10,
#   'id_left': 41978210,
#   'brand_left': nan,
#   'title_left': 'Canon 10-18mm IS STM Lens',
#   'description_left': 'The EF-S 10-18mm f/4.5-5.6 IS STM lens combines optical excellence with cutting-edge performance, providing an ultra-wide angle of view in a compact, portable package, perfect for EOS cameras with an APS-C sensor.',
#   'price_left': '399.00',
#   'priceCurrency_left': 'CAD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 3329047,
#   'id_right': 10409666,
#   'brand_right': nan,
#   'title_right': 'Canon EF-M 18-150mm f/3.5-6.3 IS STM Lens - Graphite',
#   'description_right': 'A versatile mirrorless zoom lens for shooting sharp images and movies in smooth, quiet focus',
#   'price_right': '519.0',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 3160384,
#   'pair_id': '41978210#10409666',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Epson - Vaschetta recupero toner - C13T619000. Entity 2: Epson C1100 High Capacity Cyan.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 65,
#   'prompt_tokens': 55,
#   'completion_tokens': 10,
#   'id_left': 15393429,
#   'brand_left': nan,
#   'title_left': 'Epson - Vaschetta recupero toner - C13T619000',
#   'description_left': 'Vaschetta recupero toner',
#   'price_left': '23.09',
#   'priceCurrency_left': 'EUR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 484404,
#   'id_right': 73624462,
#   'brand_right': nan,
#   'title_right': 'Epson C1100 High Capacity Cyan',
#   'description_right': 'Epson C1100 High Capacity Cyan',
#   'price_right': '151.42',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 118390,
#   'pair_id': '15393429#73624462',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: DISCO DURO EXT USB3.0 3.53TB WD MY BOOK NEGRO. Entity 2: LaCie 2TB Rugged Thunderbolt USB-C + USB 3.0.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 77,
#   'prompt_tokens': 67,
#   'completion_tokens': 10,
#   'id_left': 69392189,
#   'brand_left': nan,
#   'title_left': 'DISCO DURO EXT USB3.0 3.53TB WD MY BOOK NEGRO',
#   'description_left': 'Western Digital My Book, Unidad de disco duro, 3.0 (3.1 Gen 1), USB Type-A, Windows 10 Education, Windows 10 Education x64, Windows 10 Enterprise, Windows 10 Enterprise x64, Wi, Mac OS X 10.10 Yosemite, Mac OS X 10.11 El Capitan, Mac OS X 10.9 Maveri',
#   'price_left': '118.14',
#   'priceCurrency_left': 'EUR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 707463,
#   'id_right': 14035013,
#   'brand_right': nan,
#   'title_right': 'LaCie 2TB Rugged Thunderbolt USB-C + USB 3.0',
#   'description_right': 'LaCie 2TB Rugged Thunderbolt USB-C + USB 3.0',
#   'price_right': '156.15',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 114602,
#   'pair_id': '69392189#14035013',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Seagate IronWolf Pro ST8000NE001hard drive - 8 TB - SATA 6Gb/s. Entity 2: Jabra Evolve 20SE MS Mono Headset Head-band Black.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 76,
#   'prompt_tokens': 66,
#   'completion_tokens': 10,
#   'id_left': 70919736,
#   'brand_left': nan,
#   'title_left': 'Seagate IronWolf Pro ST8000NE001hard drive - 8 TB - SATA 6Gb/s',
#   'description_left': 'Built to maintain performanceSupport your business',
#   'price_left': '230.99',
#   'priceCurrency_left': 'GBP',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1578824,
#   'id_right': 73789823,
#   'brand_right': 'Jabra',
#   'title_right': 'Jabra Evolve 20SE MS Mono Headset Head-band Black',
#   'description_right': 'Easy call managementGet easy access to the most used functions, such as volume and mute. You can also answer and end calls directly from the control unit.Passive Noise CancellationSimply wear the headset to eliminate high-frequency noise, such as human voicesall thanks to the specially designed ear cushions. We call this passive noise cancellation.Get the basics rightUltimate noise cancellation microphoneState-of-the-art, noise-cancelling microphone eliminates background noise. The ear cushions are designed to reduce high-frequency sounds. You and your conversation partner wont struggle to hear each other.Plug-and-play setupThe headset works out of the box with all leading systems. Installation is as easy as',
#   'price_right': '46.01',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1695227,
#   'pair_id': '70919736#73789823',
#   'label': 0,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Kingston DataTraveler G4 16 GB USB-stick. Entity 2: Sapca New Era Clean Trucker 2 NY Yankees Cap.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 64,
#   'prompt_tokens': 54,
#   'completion_tokens': 10,
#   'id_left': 7066688,
#   'brand_left': 'Kingston',
#   'title_left': 'Kingston DataTraveler G4 16 GB USB-stick',
#   'description_left': nan,
#   'price_left': '7.99',
#   'priceCurrency_left': 'EUR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1915191,
#   'id_right': 5244749,
#   'brand_right': nan,
#   'title_right': 'Sapca New Era Clean Trucker 2 NY Yankees Cap',
#   'description_right': nan,
#   'price_right': '100',
#   'priceCurrency_right': 'RON',
#   'specTableContent_right': nan,
#   'cluster_id_right': 78575500,
#   'pair_id': '7066688#5244749',
#   'label': 0,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Tissot Seastar 1000 T120.407.11.041.01. Entity 2: Elixir Nanoweb Coated Acoustic Guitar String Set, Phosphor Bronze, .010-.047.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 81,
#   'prompt_tokens': 71,
#   'completion_tokens': 10,
#   'id_left': 43618856,
#   'brand_left': nan,
#   'title_left': 'Tissot Seastar 1000 T120.407.11.041.01',
#   'description_left': "Beautiful men's watch in stainless steel with sapphire crystal. The watch is with stainless steel bracelet, highlighted by the beautiful blue dial. The watch is also water resistant to 30 bar and equipped with a automatic movement.",
#   'price_left': '737,00',
#   'priceCurrency_left': 'EUR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 3457955,
#   'id_right': 75599056,
#   'brand_right': 'Elixir',
#   'title_right': 'Elixir Nanoweb Coated Acoustic Guitar String Set, Phosphor Bronze, .010-.047',
#   'description_right': "Looking for the feel of traditional guitar strings, but tired of ones that die out after one gig? Elixir introduces Acoustic Phosphor Bronze Guitar Strings with ultra-thin Nanoweb coating. Nanoweb gives your strings longer life, while recreating the bright tone and punch of non-coated strings. Guaranteed to be a guitarist's greatest friend.Many players prefer the rich, textured tone of phosphor bronze strings. These Elixir Strings capture the sweet spot of that unique phosphor bronze tone and extend it 3-5x longer than conventional strings.GaugesEBGDAE16002Extra Light.010-.047.010.014.023.030.039.04716027Custom Light.011-.052.011.015.022.032.042.05216052Light.012-.053.012.016.024.032.042.05316077Light-Medium.012-.056.012.016.024.035.045.05616182HD Light.013-.053.013.017.025.032.042.05316102Medium.013-.056.013.017.026.035.045.056E16102 E16182 E16077 E16052 E16027 E16002",
#   'price_right': '17.99',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 2603630,
#   'pair_id': '43618856#75599056',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: DYMO D1 - Glossy tape - black on white - Roll (1.9cm x 7m) - 1 roll(s). Entity 2: Dymo 53718 24mm x 7m Black on Yellow Tape.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 86,
#   'prompt_tokens': 76,
#   'completion_tokens': 10,
#   'id_left': 49744056,
#   'brand_left': nan,
#   'title_left': 'DYMO D1 - Glossy tape - black on white - Roll (1.9cm x 7m) - 1 roll(s)',
#   'description_left': 'Dymo 2000/5500 Tape 19mmx7m Black/White 45803.',
#   'price_left': '13.49',
#   'priceCurrency_left': 'GBP',
#   'specTableContent_left': nan,
#   'cluster_id_left': 103304,
#   'id_right': 4984777,
#   'brand_right': nan,
#   'title_right': 'Dymo 53718 24mm x 7m Black on Yellow Tape',
#   'description_right': nan,
#   'price_right': '19.43',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 103881,
#   'pair_id': '49744056#4984777',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Kingston DDR4-3333 16GB HyperX Predator Lifetime (HX433C16PB3K2/16). Entity 2: HyperX Fury black HX432C16FB3/16.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 77,
#   'prompt_tokens': 67,
#   'completion_tokens': 10,
#   'id_left': 78223205,
#   'brand_left': 'Kingston',
#   'title_left': 'Kingston DDR4-3333 16GB HyperX Predator Lifetime (HX433C16PB3K2/16)',
#   'description_left': nan,
#   'price_left': nan,
#   'priceCurrency_left': nan,
#   'specTableContent_left': nan,
#   'cluster_id_left': 499316,
#   'id_right': 46952690,
#   'brand_right': 'Kingston',
#   'title_right': 'HyperX Fury black HX432C16FB3/16',
#   'description_right': '16GB, DDR4, 3200MHz, CL16, XMP',
#   'price_right': '89.00',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 133673,
#   'pair_id': '78223205#46952690',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: LaCie Rugged Thunderbolt USB-C 4TB. Entity 2: PG-1170 11-Speed Cassette.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 61,
#   'prompt_tokens': 51,
#   'completion_tokens': 10,
#   'id_left': 34072942,
#   'brand_left': nan,
#   'title_left': 'LaCie Rugged Thunderbolt USB-C 4TB',
#   'description_left': nan,
#   'price_left': nan,
#   'priceCurrency_left': nan,
#   'specTableContent_left': nan,
#   'cluster_id_left': 1073295,
#   'id_right': 269919,
#   'brand_right': nan,
#   'title_right': 'PG-1170 11-Speed Cassette',
#   'description_right': "SRAM's 1170 11-Speed Cassette is constructed of light, durable materials and boasts SRAM's PowerGlide tooth profiles and shift ramps for quick, positive gear changes. This excellent cassette also...",
#   'price_right': '100.00',
#   'priceCurrency_right': 'USD',
#   'specTableContent_right': nan,
#   'cluster_id_right': 4823047,
#   'pair_id': '34072942#269919',
#   'label': 0,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': "Do the two product descriptions refer to the same real-world product? Entity 1: Traveler's Company Traveler's Company Notebook Accessories. Entity 2: Oakley Jawbreaker Black Prizm OO9290 20 131-0.",
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 67,
#   'prompt_tokens': 57,
#   'completion_tokens': 10,
#   'id_left': 45833973,
#   'brand_left': "Traveler's Company",
#   'title_left': "Traveler's Company Traveler's Company Notebook Accessories",
#   'description_left': nan,
#   'price_left': '6.00',
#   'priceCurrency_left': 'USD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 5041507,
#   'id_right': 62894191,
#   'brand_right': 'Oakley',
#   'title_right': 'Oakley Jawbreaker Black Prizm OO9290 20 131-0',
#   'description_right': 'Lunettes de soleil Oakley Jawbreaker Black Prizm OO9290 20 131-0',
#   'price_right': nan,
#   'priceCurrency_right': nan,
#   'specTableContent_right': nan,
#   'cluster_id_right': 1203171,
#   'pair_id': '45833973#62894191',
#   'label': 0,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: CORSAIR CARBIDE SPEC-01 Mid-Tower Gaming Case with Red LED Fan | CC-9011050-WW. Entity 2: Case Corsair 460X con luci red.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to Corsair gaming',
#   'chatbot_response_clean': 1,
#   'total_tokens': 76,
#   'prompt_tokens': 66,
#   'completion_tokens': 10,
#   'id_left': 39152734,
#   'brand_left': nan,
#   'title_left': 'CORSAIR CARBIDE SPEC-01 Mid-Tower Gaming Case with Red LED Fan | CC-9011050-WW',
#   'description_left': 'The Essential Gaming PC Case.Carbide Series SPEC-01 is proof that great looks, smart design, and durable construction don’t need to be pricy, and that basic doesn’t need to be boring. You get aggressive styling, a huge side panel window for admiring your components, and an LED-lit front intake fan that draws cool air directly to your graphics cards.Inside, there’s room for up to five fans, and the four combination hard drive / SSD trays make storage installation and upgrades quick and easy. Cable routing cutouts help you reduce clutter, and the built-in dust filters help protect your components. Up front,',
#   'price_left': '210',
#   'priceCurrency_left': 'AED',
#   'specTableContent_left': nan,
#   'cluster_id_left': 195552,
#   'id_right': 43851871,
#   'brand_right': nan,
#   'title_right': 'Case Corsair 460X con luci red',
#   'description_right': 'Case Dimensions440mm x 220mm x 464mmMaximum GPU Length370mmMaximum PSU Length200mmMaximum CPU Cooler Height170mmCase Expansion Slots7Case Drive Bays”(x2) 3.5in (x3) 2.5in”Case Form FactorMid-TowerCase WindowedTempered GlassCase WarrantyTwo yearsiCUE enabledNo',
#   'price_right': '184.09',
#   'priceCurrency_right': 'USD',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1320095,
#   'pair_id': '39152734#43851871',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Steering Stem Mount Base - RAM 342. Entity 2: Jabra Evolve 20 SE Mono MS USB Corded PC Headset.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 63,
#   'prompt_tokens': 53,
#   'completion_tokens': 10,
#   'id_left': 94367933,
#   'brand_left': nan,
#   'title_left': 'Steering Stem Mount Base - RAM 342',
#   'description_left': 'The RAM fork stem mount is one of the cleanest ways to mount small electronics on your motorcycle. Simply slide the assembly into the hole of the stem and tighten the machine screw to create a tight fit. This part is designed to fit into the cylindrical bore wall of fork stems and will work with stems that measure from 12 -20mm and 28mm or .5” – 1.10” at the following intervals: Metric Standard 12mm .5” 14mm .55” 16mm .63” 18mm .71” 20mm .79” 28mm 1.10” Material:Powder Coated Marine Grade Aluminum Ball Size:1\\" Rubber Ball \\"B\\" Size Note:RAM recommends that',
#   'price_left': '15.95',
#   'priceCurrency_left': 'USD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 2039173,
#   'id_right': 36616040,
#   'brand_right': 'Jabra',
#   'title_right': 'Jabra Evolve 20 SE Mono MS USB Corded PC Headset',
#   'description_right': 'Jabra Evolve 20 SE Mono MS USB Headset from Headset Store. Next Day Delivery. Part Code:4993-823-309',
#   'price_right': '47.99',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1695227,
#   'pair_id': '94367933#36616040',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Switch DGS-1210-24P 24 porturi. Entity 2: WS-C2960X-24PD-L - 24 Port Switch.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 67,
#   'prompt_tokens': 57,
#   'completion_tokens': 10,
#   'id_left': 2244475,
#   'brand_left': 'D-link',
#   'title_left': 'Switch DGS-1210-24P 24 porturi',
#   'description_left': 'D-Link, Smart Switch 24 porturi 10/100/1000 Gigabit PoE, 4 SFP, Smart, Switching capacity 56Gbps, budget 85W',
#   'price_left': '1,409.99 Lei;',
#   'priceCurrency_left': nan,
#   'specTableContent_left': nan,
#   'cluster_id_left': 964764,
#   'id_right': 26844226,
#   'brand_right': nan,
#   'title_right': 'WS-C2960X-24PD-L - 24 Port Switch',
#   'description_right': 'Cisco Catalyst 2960-X 24 Port 370W PoE LAN Base Ethernet Switch',
#   'price_right': '1364.00',
#   'priceCurrency_right': 'USD',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1412234,
#   'pair_id': '2244475#26844226',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: EPSON - Ink Cart/XL Yellow WF-8xxx. Entity 2: Epson Light Black Ink Cartridge 220ml.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 62,
#   'prompt_tokens': 52,
#   'completion_tokens': 10,
#   'id_left': 28403450,
#   'brand_left': nan,
#   'title_left': 'EPSON - Ink Cart/XL Yellow WF-8xxx',
#   'description_left': 'EPSON Ink Cart/XL Yellow WF-8xxx (C13T755440) - Produkt: Blekk',
#   'price_left': '901.25',
#   'priceCurrency_left': 'NOK',
#   'specTableContent_left': nan,
#   'cluster_id_left': 2806654,
#   'id_right': 76837299,
#   'brand_right': nan,
#   'title_right': 'Epson Light Black Ink Cartridge 220ml',
#   'description_right': 'The Epson Light Black Ink Cartridge 220ml (C13T603700) is an Ink cartridge manufactured by Epson and is 220ml.',
#   'price_right': nan,
#   'priceCurrency_right': nan,
#   'specTableContent_right': nan,
#   'cluster_id_right': 786291,
#   'pair_id': '28403450#76837299',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Jabra Biz 2300 USB Duo Headset. Entity 2: SHIMANO PD-R550 SPD-SL PEDAL BLK.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 63,
#   'prompt_tokens': 53,
#   'completion_tokens': 10,
#   'id_left': 5578260,
#   'brand_left': nan,
#   'title_left': 'Jabra Biz 2300 USB Duo Headset',
#   'description_left': 'The Jabra Biz 2300 USB Duo is a dual ear noise cancelling headset designed for Unified Communication (UC) and Skype for Business (SFB) environments.Audio features include a Noise Cancelling Microphone to reduce background noise, wideband audio technology and DSP technology for better clarity.The Jabra Biz 2300 series is built to last, with a reinforced Kevlar cord and unbreakable boom arm the 2300 series can withstand any punishment a high performing contact centre can give.',
#   'price_left': '108.00',
#   'priceCurrency_left': 'EUR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 666306,
#   'id_right': 27263164,
#   'brand_right': 'SHIMANO',
#   'title_right': 'SHIMANO PD-R550 SPD-SL PEDAL BLK',
#   'description_right': 'Shimano Tiagra Pedal',
#   'price_right': '110.00',
#   'priceCurrency_right': 'AUD',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1385673,
#   'pair_id': '5578260#27263164',
#   'label': 0,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: ASUS Placa video DUAL RTX2060 OC EVO, 6GB GDDR6 192bit. Entity 2: Asus Nvidia RTX 2060 SUPER Turbo EVO OC 8Gb GDDR6.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 81,
#   'prompt_tokens': 71,
#   'completion_tokens': 10,
#   'id_left': 6988926,
#   'brand_left': 'ASUS',
#   'title_left': 'ASUS Placa video DUAL RTX2060 OC EVO, 6GB GDDR6 192bit',
#   'description_left': 'Placa video Asus DUAL RTX2060 OC EVO 6GB GDDR6, DUAL-RTX2060-O6G-EVO, NVIDIA GeForce RTX 2060, Interface PCI Express 3.0, GDDR6 6GB, Memory Clock 14000 MHz, Memory Interface 192-bit, OC Mode - GPU Boost Clock : 1785 MHz , GPU Base Clock : 1395 MHz, Gaming Mode (Default) - GPU Boost Clock : 1755 MHz , GPU Base Clock : 1365 MHz, DVI Output : Yes x 1 (Native) (DVI-D), HDMI Output : Yes x 2 (Native) (HDMI 2.0b), Display Port : Yes x 1 (Native) (DisplayPort 1.4), HDCP Support : Yes (2.2)',
#   'price_left': '1843.81',
#   'priceCurrency_left': 'RON',
#   'specTableContent_left': nan,
#   'cluster_id_left': 697270,
#   'id_right': 23158552,
#   'brand_right': nan,
#   'title_right': 'Asus Nvidia RTX 2060 SUPER Turbo EVO OC 8Gb GDDR6',
#   'description_right': 'ASUS Turbo GeForce® RTX 2060 SUPER™ EVO 8GB GDDR6 with a blower-style design for AAA gaming performance and ray tracing',
#   'price_right': '439',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 320546,
#   'pair_id': '6988926#23158552',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: DYMO D1 - Glossy tape - black on white - Roll (1.9cm x 7m) - 1 roll(s). Entity 2: D-link DGS-1210-24P best price.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 81,
#   'prompt_tokens': 71,
#   'completion_tokens': 10,
#   'id_left': 49744056,
#   'brand_left': nan,
#   'title_left': 'DYMO D1 - Glossy tape - black on white - Roll (1.9cm x 7m) - 1 roll(s)',
#   'description_left': 'Dymo 2000/5500 Tape 19mmx7m Black/White 45803.',
#   'price_left': '13.49',
#   'priceCurrency_left': 'GBP',
#   'specTableContent_left': nan,
#   'cluster_id_left': 103304,
#   'id_right': 43742288,
#   'brand_right': nan,
#   'title_right': 'D-link DGS-1210-24P best price',
#   'description_right': '24-Port Gigabit PoE Smart Switch with 4 SFP ports Price: 261.18. Best price from OmniChannel. Convenient payment by bank transfer or delivery',
#   'price_right': '2.6118E2',
#   'priceCurrency_right': 'eur',
#   'specTableContent_right': nan,
#   'cluster_id_right': 964764,
#   'pair_id': '49744056#43742288',
#   'label': 0,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Kingston Gaming Memory 16 Gb 3200 Mhz Ddr4 Nonecc Dimm Cl16 Limited Lifetime Warranty. Entity 2: Memoria Notebook Ddr4 4gb 2400mhz Kingston.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 79,
#   'prompt_tokens': 69,
#   'completion_tokens': 10,
#   'id_left': 83958613,
#   'brand_left': nan,
#   'title_left': 'Kingston Gaming Memory 16 Gb 3200 Mhz Ddr4 Nonecc Dimm Cl16 Limited Lifetime Warranty',
#   'description_left': 'KINGSTON GAMING MEMORY 16GB 3200MHZ DDR4 NONECC DIMM CL16 LIMITED LIFETIME WARRANTY',
#   'price_left': '2.229E3',
#   'priceCurrency_left': 'ZAR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 133673,
#   'id_right': 24449788,
#   'brand_right': 'KINGSTON',
#   'title_right': 'Memoria Notebook Ddr4 4gb 2400mhz Kingston',
#   'description_right': nan,
#   'price_right': '230.8',
#   'priceCurrency_right': 'BRL',
#   'specTableContent_right': nan,
#   'cluster_id_right': 352020,
#   'pair_id': '83958613#24449788',
#   'label': 0,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Audio Technica ATHM50X Professional Monitor Headphones. Entity 2: Manfrotto MVH 500 AH Video hoved.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 63,
#   'prompt_tokens': 53,
#   'completion_tokens': 10,
#   'id_left': 43759195,
#   'brand_left': nan,
#   'title_left': 'Audio Technica ATHM50X Professional Monitor Headphones',
#   'description_left': 'The M-Series ATH-M40x professional monitor headphones are tuned flat for incredibly accurate audio monitoring across an extended frequency range. Your studio experience is enhanced with superior sound isolation and swiveling earcups for convenient one-ear monitoring. Engineered with pro-grade materials and robust construction, the M40x excels in professional studio tracking and mixing, as well as DJ monitoring.Critically acclaimed M-Series professional monitor headphones deliver accurate audio and outstanding comfort, perfect for long sessions in the studio and on the go. Contoured earcups seal tight for excellent sound isolation, with minimal bleed. And the pro-grade materials are durable, yet comfortable. Find out why',
#   'price_left': '149.95',
#   'priceCurrency_left': 'USD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1889634,
#   'id_right': 9646081,
#   'brand_right': 'Manfrotto',
#   'title_right': 'Manfrotto MVH 500 AH Video hoved',
#   'description_right': 'Manfrotto Videohoved MVH500AH Flatbase',
#   'price_right': '1095',
#   'priceCurrency_right': 'DKK',
#   'specTableContent_right': nan,
#   'cluster_id_right': 72631,
#   'pair_id': '43759195#9646081',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: ADAPTADOR WIRELESS USB DB ARCHER T2U AC600 TP-LINK. Entity 2: TP-Link TL-WN781ND PCI Express Wireless Adapter.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 70,
#   'prompt_tokens': 60,
#   'completion_tokens': 10,
#   'id_left': 61883869,
#   'brand_left': nan,
#   'title_left': 'ADAPTADOR WIRELESS USB DB ARCHER T2U AC600 TP-LINK',
#   'description_left': nan,
#   'price_left': '154.56',
#   'priceCurrency_left': 'BRL',
#   'specTableContent_left': nan,
#   'cluster_id_left': 373003,
#   'id_right': 69151064,
#   'brand_right': nan,
#   'title_right': 'TP-Link TL-WN781ND PCI Express Wireless Adapter',
#   'description_right': 'TP-Link TL-WN781ND PCI Express Wireless AdapterTP-Link TL-WN781ND PCI Express Wireless Adapter Wireless-N provides fast wireless speeds of up to 150 Mbps PCI express connector is widely compatible QSS function to ensure wireless network security 150Mbps Wireless N PCI Express Adapter - TL-WN781ND',
#   'price_right': '2200.00',
#   'priceCurrency_right': 'KES',
#   'specTableContent_right': nan,
#   'cluster_id_right': 466493,
#   'pair_id': '61883869#69151064',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: D-Link DGS-1210-24. Entity 2: Switch DGS-1210-24P 24 porturi.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 63,
#   'prompt_tokens': 53,
#   'completion_tokens': 10,
#   'id_left': 65657820,
#   'brand_left': nan,
#   'title_left': 'D-Link DGS-1210-24',
#   'description_left': 'The DGS-1210-24 is part of D-Link’s 3rd generation of Web Smart Switches that integrates advanced management and security functions for performance and scalability.Featuring an innovative fanless design that ensures quiet operation and a longer life span, the DGS-1210-24 provides a complete and affordable solution for small and medium businesses (SMB).Seamless IntegrationThe DGS-1210-24 includes 24 10/100/1000 Mbps ports capable of connecting to existing Cat.5 twisted-pair cables.Additionally, the last four ports of the DGS-1210-24 combine SFP and copper connectivity into one port and therefore provide a flexible solution for server connections via fiber interface. Using the default presets, the administrator can quickly',
#   'price_left': '126.15',
#   'priceCurrency_left': 'GBP',
#   'specTableContent_left': nan,
#   'cluster_id_left': 793378,
#   'id_right': 2244475,
#   'brand_right': 'D-link',
#   'title_right': 'Switch DGS-1210-24P 24 porturi',
#   'description_right': 'D-Link, Smart Switch 24 porturi 10/100/1000 Gigabit PoE, 4 SFP, Smart, Switching capacity 56Gbps, budget 85W',
#   'price_right': '1,409.99 Lei;',
#   'priceCurrency_right': nan,
#   'specTableContent_right': nan,
#   'cluster_id_right': 964764,
#   'pair_id': '65657820#2244475',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': "Do the two product descriptions refer to the same real-world product? Entity 1: Epson Cartouche d encre magenta PP-100 (PJIC4) (C13S020450). Entity 2: Cartouche d'encre Epson Epson cartouche wf-8xxx - noir xl.",
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 84,
#   'prompt_tokens': 74,
#   'completion_tokens': 10,
#   'id_left': 76444213,
#   'brand_left': 'EPSON',
#   'title_left': 'Epson Cartouche d encre magenta PP-100 (PJIC4) (C13S020450)',
#   'description_left': 'Ink Cartridge, Magenta',
#   'price_left': nan,
#   'priceCurrency_left': nan,
#   'specTableContent_left': nan,
#   'cluster_id_left': 2284784,
#   'id_right': 41493099,
#   'brand_right': 'EPSON',
#   'title_right': "Cartouche d'encre Epson Epson cartouche wf-8xxx - noir xl",
#   'description_right': "Cartouche d'encre Epson Epson cartouche wf-8xxx - noir xl",
#   'price_right': '79.79',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 3543965,
#   'pair_id': '76444213#41493099',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Garmin Fenix 5S Plus GPS Multisport Watch with HR - Black. Entity 2: Omega Seamaster Planet Ocean Chrono for Men.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 65,
#   'prompt_tokens': 55,
#   'completion_tokens': 10,
#   'id_left': 53380330,
#   'brand_left': nan,
#   'title_left': 'Garmin Fenix 5S Plus GPS Multisport Watch with HR - Black',
#   'description_left': nan,
#   'price_left': '479',
#   'priceCurrency_left': 'GBP',
# ...
#   'priceCurrency_left': 'AUD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 861125,
#   'id_right': 47322028,
#   'brand_right': 'Corsair',
#   'title_right': 'Corsair Vengeance Lpx 16 Gb (2x8 Gb) Ddr4 Dram Dimm 3200 M Hz C16 Black Heat Spreader',
#   'description_right': 'Designed for high-performance overclocking on Intel 100 Series motherboardsVengeance LPX memory i...',
#   'price_right': '0.0',
#   'priceCurrency_right': 'AUD',
#   'specTableContent_right': nan,
#   'cluster_id_right': 760884,
#   'pair_id': '18159593#47322028',
#   'label': 0,
#   'is_hard_negative': True},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Epson T6031 Patron Photo Black 220ml (Eredeti). Entity 2: Fujifilm XF 8-16mm f/2.8 R LM WR Zoom Lens.',
#   'chatbot_response_raw': 'No, the two product descriptions do not refer to',
#   'chatbot_response_clean': 0,
#   'total_tokens': 74,
#   'prompt_tokens': 64,
#   'completion_tokens': 10,
#   'id_left': 8631493,
#   'brand_left': nan,
#   'title_left': 'Epson T6031 Patron Photo Black 220ml (Eredeti)',
#   'description_left': '220mlStylus Pro 7800/7880/9800/9880',
#   'price_left': '41395',
#   'priceCurrency_left': 'HUF',
#   'specTableContent_left': nan,
#   'cluster_id_left': 413734,
#   'id_right': 80918812,
#   'brand_right': 'Fujifilm',
#   'title_right': 'Fujifilm XF 8-16mm f/2.8 R LM WR Zoom Lens',
#   'description_right': 'The Fujifilm XF 8-16mm f/2.8 R LM WR is a fast ultra-wide-angle zoom lens with outstanding edge-to-edge image-resolving performance and f/2.8 maximum aperture that make this product a perfect choice for landscape and architecture photography.',
#   'price_right': '42995.00',
#   'priceCurrency_right': 'ZAR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 37091,
#   'pair_id': '8631493#80918812',
#   'label': 0,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Shimano CN-HG901 11 Speed Chain. Entity 2: 11Shimano - (HG901) XTR / DURA ACE 116 Links.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 69,
#   'prompt_tokens': 59,
#   'completion_tokens': 10,
#   'id_left': 88985066,
#   'brand_left': 'Shimano',
#   'title_left': 'Shimano CN-HG901 11 Speed Chain',
#   'description_left': nan,
#   'price_left': '85.00',
#   'priceCurrency_left': 'NZD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1037461,
#   'id_right': 46518287,
#   'brand_right': nan,
#   'title_right': '11Shimano - (HG901) XTR / DURA ACE 116 Links',
#   'description_right': '11XTR -Dura Ace.Sil-Tec.116 ..',
#   'price_right': '205.00',
#   'priceCurrency_right': 'ILS',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1037461,
#   'pair_id': '88985066#46518287',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: T7 Portable SSD - 2TB Indigo Blue. Entity 2: Samsung Portable SSD T7 MU-PC2T0Hsolid state drive - 2 TB - USB 3.2 Gen 2.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 79,
#   'prompt_tokens': 69,
#   'completion_tokens': 10,
#   'id_left': 52588862,
#   'brand_left': nan,
#   'title_left': 'T7 Portable SSD - 2TB Indigo Blue',
#   'description_left': 'Light and pocket-sized, the Portable SSD T7 both delivers fast speeds and safeguards data for an easy way to store and transfer large files. Experience everyday high performance in your work and play with the T7.',
#   'price_left': '639.99',
#   'priceCurrency_left': 'NZD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1252792,
#   'id_right': 72004049,
#   'brand_right': nan,
#   'title_right': 'Samsung Portable SSD T7 MU-PC2T0Hsolid state drive - 2 TB - USB 3.2 Gen 2',
#   'description_right': 'External storage, evolvedTransfer in a flashSecure with a touch',
#   'price_right': '330.35',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1252792,
#   'pair_id': '52588862#72004049',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: D1-TAPE 24MM X 7M noir ON blanc IN. Entity 2: DYMO D1 - Glossy tape - black on white - Roll (2.4 cm x 7 m) - 1 roll(s).',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 84,
#   'prompt_tokens': 74,
#   'completion_tokens': 10,
#   'id_left': 48920124,
#   'brand_left': nan,
#   'title_left': 'D1-TAPE 24MM X 7M noir ON blanc IN',
#   'description_left': 'S0720930 Dymo',
#   'price_left': '0',
#   'priceCurrency_left': 'EUR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 395055,
#   'id_right': 22463957,
#   'brand_right': nan,
#   'title_right': 'DYMO D1 - Glossy tape - black on white - Roll (2.4 cm x 7 m) - 1 roll(s)',
#   'description_right': 'Labels can be removed without leaving adhesive residue, Adheres to almost all clean, flat surfaces including plastic, paper, metal, wood and...',
#   'price_right': '15.48',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 395055,
#   'pair_id': '48920124#22463957',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Planet Ocean 600M Omega Co-Axial Chronograph 45.5mm 232.30.46.51.01.002. Entity 2: Omega Seamaster Planet Ocean Chrono for Men.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 78,
#   'prompt_tokens': 68,
#   'completion_tokens': 10,
#   'id_left': 14287942,
#   'brand_left': 'Omega',
#   'title_left': 'Planet Ocean 600M Omega Co-Axial Chronograph 45.5mm 232.30.46.51.01.002',
#   'description_left': "Planet Ocean 600M Omega Co-Axial Chronograph 45.5mm It was with OMEGA's maritime legacy in mind that the brand launched its Planet Ocean line in 2005. The stylish OMEGA Seamaster Planet Ocean 600M pays homage to OMEGA's dive watch heritage.This model, with its scratch-resistant sapphire crystal, features a black dial with a small seconds dial, a date window and a central chronograph hand. Sixty-minute and 12-hour counters are found on the same dial at the 3 o'clock position, allowing for intuitive reading of the elapsed time. The orange unidirectional rotating divers' bezel is mounted on a 45.5 mm stainless steel case",
#   'price_left': '8000',
#   'priceCurrency_left': 'USD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 5409130,
#   'id_right': 25758185,
#   'brand_right': 'OMEGA',
#   'title_right': 'Omega Seamaster Planet Ocean Chrono for Men',
#   'description_right': 'Omega Seamaster Planet Ocean Chrono for Men - this product is manufactured by OMEGA in Switzerland (and maybe in other countries)',
#   'price_right': nan,
#   'priceCurrency_right': nan,
#   'specTableContent_right': nan,
#   'cluster_id_right': 5409130,
#   'pair_id': '14287942#25758185',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: MONITOR LED 23.8BENQ GW2480 MMEDIA NEGRO. Entity 2: BenQ GW2480 - LED-monitor - 23.8\\" - 1920 x 1080 Full HD - IPS.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 83,
#   'prompt_tokens': 73,
#   'completion_tokens': 10,
#   'id_left': 28534061,
#   'brand_left': nan,
#   'title_left': 'MONITOR LED 23.8BENQ GW2480 MMEDIA NEGRO',
#   'description_left': 'MONITOR LED 23.8BENQ GW2480 MMEDIA NEGRO HDMI+VGA+DP/1920X1080/IPS/5ms/VESA 100X100 9H.LGDLA.TBE',
#   'price_left': '144.96',
#   'priceCurrency_left': 'EUR',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1044678,
#   'id_right': 4402971,
#   'brand_right': 'BenQ',
#   'title_right': 'BenQ GW2480 - LED-monitor - 23.8\\" - 1920 x 1080 Full HD - IPS',
#   'description_right': 'BenQ GW2480 - LED-monitor - 23.8\\" - 1920 x 1080 Full HD - IPS - 250 cd/m2 - 1000:1 - 5 ms - HDMI, VGA, DisplayPort - luidsprekers - zwart',
#   'price_right': '€134,00',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1044678,
#   'pair_id': '28534061#4402971',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Jabra Evolve 65 Headset UC Mono. Entity 2: JABRA EVOLVE 65 UC MONO c/w LINK 360.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 65,
#   'prompt_tokens': 55,
#   'completion_tokens': 10,
#   'id_left': 54856190,
#   'brand_left': nan,
#   'title_left': 'Jabra Evolve 65 Headset UC Mono',
#   'description_left': nan,
#   'price_left': '11990',
#   'priceCurrency_left': 'PHP',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1409979,
#   'id_right': 59929353,
#   'brand_right': nan,
#   'title_right': 'JABRA EVOLVE 65 UC MONO c/w LINK 360',
#   'description_right': '7% GST excluded.',
#   'price_right': '255.68',
#   'priceCurrency_right': 'SGD',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1409979,
#   'pair_id': '54856190#59929353',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: ASUS GRAPHICS CARD DUAL RTX 2060 OC EVO 6GB DDR6 2X HDMI 1X DVI-D 1 X DISPLAY PORT 2 X FAN MAX DISPLAY SUPPORT:4 500W 3 YEAR CARRY IN WARRANTY. Entity 2: ASUS Placa video DUAL RTX2060 OC EVO, 6GB GDDR6 192bit.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 117,
#   'prompt_tokens': 107,
#   'completion_tokens': 10,
#   'id_left': 37463999,
#   'brand_left': nan,
#   'title_left': 'ASUS GRAPHICS CARD DUAL RTX 2060 OC EVO 6GB DDR6 2X HDMI 1X DVI-D 1 X DISPLAY PORT 2 X FAN MAX DISPLAY SUPPORT:4 500W 3 YEAR CARRY IN WARRANTY',
#   'description_left': nan,
#   'price_left': nan,
#   'priceCurrency_left': nan,
#   'specTableContent_left': nan,
#   'cluster_id_left': 697270,
#   'id_right': 6988926,
#   'brand_right': 'ASUS',
#   'title_right': 'ASUS Placa video DUAL RTX2060 OC EVO, 6GB GDDR6 192bit',
#   'description_right': 'Placa video Asus DUAL RTX2060 OC EVO 6GB GDDR6, DUAL-RTX2060-O6G-EVO, NVIDIA GeForce RTX 2060, Interface PCI Express 3.0, GDDR6 6GB, Memory Clock 14000 MHz, Memory Interface 192-bit, OC Mode - GPU Boost Clock : 1785 MHz , GPU Base Clock : 1395 MHz, Gaming Mode (Default) - GPU Boost Clock : 1755 MHz , GPU Base Clock : 1365 MHz, DVI Output : Yes x 1 (Native) (DVI-D), HDMI Output : Yes x 2 (Native) (HDMI 2.0b), Display Port : Yes x 1 (Native) (DisplayPort 1.4), HDCP Support : Yes (2.2)',
#   'price_right': '1843.81',
#   'priceCurrency_right': 'RON',
#   'specTableContent_right': nan,
#   'cluster_id_right': 697270,
#   'pair_id': '37463999#6988926',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Ubiquiti UAP-AC-PRO-5 Wi-Fi, 802.11 a/b/g/n/ac, 2.4/5.0 GHz, 2, Web-based management, 1.3 Gbit/s, Power over Ethernet (PoE), 10,. Entity 2: UBIQUITI UNIFI UAP-AC-PRO-5 (5-Pack).',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 115,
#   'prompt_tokens': 105,
#   'completion_tokens': 10,
#   'id_left': 37994614,
#   'brand_left': nan,
#   'title_left': 'Ubiquiti UAP-AC-PRO-5 Wi-Fi, 802.11 a/b/g/n/ac, 2.4/5.0 GHz, 2, Web-based management, 1.3 Gbit/s, Power over Ethernet (PoE), 10,',
#   'description_left': nan,
#   'price_left': '2984.79',
#   'priceCurrency_left': 'PLN',
#   'specTableContent_left': nan,
#   'cluster_id_left': 68127,
#   'id_right': 50979472,
#   'brand_right': nan,
#   'title_right': 'UBIQUITI UNIFI UAP-AC-PRO-5 (5-Pack)',
#   'description_right': nan,
#   'price_right': '3110.04',
#   'priceCurrency_right': 'PLN',
#   'specTableContent_right': nan,
#   'cluster_id_right': 68127,
#   'pair_id': '37994614#50979472',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: Canon EF-S 55-250mm F4-5.6 STM IS Zoom Lens. Entity 2: Canon EF-S 55-250mm f/4-5.6 IS STM SLR Telephoto lens Black.',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 81,
#   'prompt_tokens': 71,
#   'completion_tokens': 10,
#   'id_left': 73206113,
#   'brand_left': 'Canon',
#   'title_left': 'Canon EF-S 55-250mm F4-5.6 STM IS Zoom Lens',
#   'description_left': 'Canon EF-S 55-250mm F4-5.6 STM IS Zoom Lens',
#   'price_left': '449',
#   'priceCurrency_left': 'AUD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 1109911,
#   'id_right': 86065131,
#   'brand_right': nan,
#   'title_right': 'Canon EF-S 55-250mm f/4-5.6 IS STM SLR Telephoto lens Black',
#   'description_right': 'Shop wide range of camera lenses online for camera accessories. Get products with high quality and material at buy4lesstoday. Order online today!',
#   'price_right': '2.9938E2',
#   'priceCurrency_right': 'GBP',
#   'specTableContent_right': nan,
#   'cluster_id_right': 1109911,
#   'pair_id': '73206113#86065131',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': 'Do the two product descriptions refer to the same real-world product? Entity 1: APC APCRBC133 Replacement Battery Cartridge #133. Entity 2: APC APCRBC133 Sealed Lead Acid (VRLA).',
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 64,
#   'prompt_tokens': 54,
#   'completion_tokens': 10,
#   'id_left': 36784297,
#   'brand_left': nan,
#   'title_left': 'APC APCRBC133 Replacement Battery Cartridge #133',
#   'description_left': 'APC APCRBC133 Replacement Battery Cartridge #133',
#   'price_left': '539',
#   'priceCurrency_left': 'SGD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 167983,
#   'id_right': 29457595,
#   'brand_right': nan,
#   'title_right': 'APC APCRBC133 Sealed Lead Acid (VRLA)',
#   'description_right': 'APC APCRBC133, Sealed Lead Acid (VRLA), 1 pc(s), Black, 432 VAh, 5 year(s), REACH No SVHCs',
#   'price_right': '0.0',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 167983,
#   'pair_id': '36784297#29457595',
#   'label': 1,
#   'is_hard_negative': False},
#  {'task': 'domain-complex-free (Product)',
#   'chatbot_question': "Do the two product descriptions refer to the same real-world product? Entity 1: Tissot Stainless Steel T-Sport Men's Watch - T1204071704100. Entity 2: Tissot Seastar 1000 T120.407.17.041.00.",
#   'chatbot_response_raw': 'Yes, both product descriptions refer to the same real',
#   'chatbot_response_clean': 1,
#   'total_tokens': 77,
#   'prompt_tokens': 67,
#   'completion_tokens': 10,
#   'id_left': 69688331,
#   'brand_left': 'Tissot',
#   'title_left': "Tissot Stainless Steel T-Sport Men's Watch - T1204071704100",
#   'description_left': 'The automatic choice',
#   'price_left': '690.00',
#   'priceCurrency_left': 'USD',
#   'specTableContent_left': nan,
#   'cluster_id_left': 973707,
#   'id_right': 21293905,
#   'brand_right': nan,
#   'title_right': 'Tissot Seastar 1000 T120.407.17.041.00',
#   'description_right': nan,
#   'price_right': '695.00',
#   'priceCurrency_right': 'EUR',
#   'specTableContent_right': nan,
#   'cluster_id_right': 973707,
#   'pair_id': '69688331#21293905',
#   'label': 1,
#   'is_hard_negative': False},
#  ...]

# %%
df = pd.read_json(f"../results/gpt-3.5-turbo-0125/2024-06-15-14-03-56_wdc_testset.json")
# Give me the total prompt and completion tokens
print(df['prompt_tokens'].sum())
print(df['completion_tokens'].sum())
# Out:
# 87303
# 12390

# %%
all_columns = ['task', 'chatbot_question', 'chatbot_response_raw', 'chatbot_response_clean',"total_tokens"] + list(df.columns)
 # Convert the list of dictionaries to a DataFrame
results_df = pd.DataFrame(result_rows, columns=all_columns)

# get the current date and time
now = datetime.now()

directory = f"{base_path}"
if not os.path.exists(directory):
    os.makedirs(directory)
# save the dataframe as a json file
results_df.to_json(f"{base_path}/{now.strftime('%Y-%m-%d-%H-%M-%S')}_wdc_complex_free.json")

# %%
results_df[results_df["chatbot_response_clean"] == results_df["label"]].shape[0] / results_df.shape[0]
# Out:
# 0.9467312348668281

# %%
df = pd.read_json("../results/gpt-3.5-turbo-0125/2024-04-06-00-10-00_wdc_complex_free.json")
df
# Out:
#                                task  \
# 0     domain-complex-free (Product)
# 1     domain-complex-free (Product)
# 2     domain-complex-free (Product)
# 3     domain-complex-free (Product)
# 4     domain-complex-free (Product)
# ...                             ...
# 4951  domain-simple-force (Product)
# 4952  domain-simple-force (Product)
# 4953  domain-simple-force (Product)
# 4954  domain-simple-force (Product)
# 4955  domain-simple-force (Product)
#
#                                        chatbot_question  \
# 0     Do the two product descriptions refer to the s...
# 1     Do the two product descriptions refer to the s...
# 2     Do the two product descriptions refer to the s...
# 3     Do the two product descriptions refer to the s...
# 4     Do the two product descriptions refer to the s...
# ...                                                 ...
# 4951  Do the two product descriptions match? Answer ...
# 4952  Do the two product descriptions match? Answer ...
# 4953  Do the two product descriptions match? Answer ...
# 4954  Do the two product descriptions match? Answer ...
# 4955  Do the two product descriptions match? Answer ...
#
#                 chatbot_response_raw  chatbot_response_clean  total_tokens  \
# 0     Yes, both product descriptions                       1            73
# 1                No, the two product                       0            85
# 2     Yes, both product descriptions                       1           136
# 3     Yes, both product descriptions                       1            85
# 4                No, the two product                       0            86
# ...                              ...                     ...           ...
# 4951                             Yes                       1           145
# 4952                             Yes                       1           134
# 4953                             Yes                       1           172
# 4954                              No                       0           103
# 4955                             Yes                       1            90
#
#        id_left     brand_left  \
# 0     67017951           None
# 1     41364196           None
# 2     49744056           None
# 3     63587638        Samsung
# 4     25138178           None
# ...        ...            ...
# 4951  16319132           None
# 4952  91699237           None
# 4953  69931309           None
# 4954  92956854  Cooler Master
# 4955   5303451           None
#
#                                              title_left  \
# 0                 Ubiquiti UniFi Protect Video Security
# 1         Kšiltovka New Era Clean Trucker Chicago Bulls
# 2     DYMO D1 - Glossy tape - black on white - Roll ...
# 3     SAMSUNG T7 Touch Black 2TB Portable SSD with F...
# 4        Kingston Canvas 128GB Micro SDXC C10 U1 V10 A1
# ...                                                 ...
# 4951             Sigma 35mm f/1.4 DG HSM Art Lens Canon
# 4952  CM / CoolerMaster MasterCase H500 ARGB ATX Cas...
# 4953  Corsair DDR4 8GB 2133Mhz CL15 Dimm Valueselect...
# 4954  Cooler Master MasterBox Lite 5 ATX Case Window...
# 4955    Ubiquiti UniFi Video G3 Infrared Range Extender
#
#                                        description_left price_left  ...  \
# 0     Ubiquiti's UniFi Protect offers all the flexib...       None  ...
# 1                                                  None        658  ...
# 2        Dymo 2000/5500 Tape 19mmx7m Black/White 45803.      13.49  ...
# 3     2TB Samsung T7 Touch MU-PC2T0K/WW, Portable Ex...     365.99  ...
# 4                                                  None      39.95  ...
# ...                                                 ...        ...  ...
# 4951  67mm Filter Size f/1.4 Aperture N/A Stabilized...     699.00  ...
# 4952                                     Warranty : N/A     159.00  ...
# 4953  Corsair Value Select 8GB PC4-17000, 8 GB, DDR4...       29.1  ...
# 4954  Motherboard compatibility :ATX, Micro-ATX, Min...       85.0  ...
# 4955  The IR Range Extender is a 'Plug and Play' acc...      70.80  ...
#
#                    brand_right  \
# 0                         None
# 1                         None
# 2                         DYMO
# 3                         None
# 4                         None
# ...                        ...
# 4951                      None
# 4952                      None
# 4953                   Corsair
# 4954                      None
# 4955  Ubiquiti Networks (UBNT)
#
#                                             title_right  \
# 0       Ubiquiti UniFi Video G3 Infrared Range Extender
# 1         Kšiltovka New Era New York Yankees MLB 9Fifty
# 2      DYMO 45017 D1 Tape 12mm x 7m sort p rd, S0720570
# 3                     T7 Portable SSD - 2TB Indigo Blue
# 4                    Transcend SSD230S 128GB best price
# ...                                                 ...
# 4951  SIGMA35mm/1.4 DG HSM | ART [Canon EF-mount]E67...
# 4952  Cooler Master Mastercase H500 ARGB Midi Tower ...
# 4953  CORSAIR DDR4 2133MHZ 8GB 1x288 DIMM 1.20V Unbu...
# 4954                           CM Case MasterBox Lite 5
# 4955   Ubiquiti UniFi video Camera G3 IR Range Extender
#
#                                       description_right  price_right  \
# 0     The IR Range Extender is a 'Plug and Play' acc...        70.80
# 1                                                  None          810
# 2     Originalt DYMO 45017 D1-tape SORT/RD Passer ti...       139.00
# 3     Light and pocket-sized, the Portable SSD T7 bo...       639.99
# 4     Transcend 128GB 2.5\" SSD230S SATA3 3D NAND Fl...      2.208E1
# ...                                                 ...          ...
# 4951                                               None         None
# 4952                                               None       114,95
# 4953                                               None        32.15
# 4954                   CM Case MasterBox Lite 5 Kucista       144.00
# 4955   Ubiquiti UniFi video Camera G3 IR Range Extender        89.09
#
#      priceCurrency_right specTableContent_right cluster_id_right  \
# 0                    GBP                    NaN           711907
# 1                    CZK                    NaN         76491423
# 2                    DKK                    NaN            48435
# 3                    NZD                    NaN          1252792
# 4                    eur                    NaN           715391
# ...                  ...                    ...              ...
# 4951                None                    NaN           704991
# 4952                 EUR                    NaN          1473407
# 4953                 EUR                    NaN          2861749
# 4954                 BAM                    NaN          1006147
# 4955                 GBP                    NaN           711907
#
#                 pair_id label  is_hard_negative
# 0      67017951#5303451     0              True
# 1     41364196#29165749     0              True
# 2     49744056#66087579     0              True
# 3     63587638#52588862     0              True
# 4     25138178#45664586     0              True
# ...                 ...   ...               ...
# 4951  16319132#54637257     1             False
# 4952  91699237#13684723     1             False
# 4953  69931309#38788118     1             False
# 4954  92956854#42906184     1             False
# 4955   5303451#41497032     1             False
#
# [4956 rows x 24 columns]

# %%
# create a new column for the chatbot response
df['chatbot_response'] = ''
df['chatbot_response_raw'] = ''
df['chatbot_question'] = ''

# %%
# loop through the dataframe and send the messages to the chatbot
for index, row in tqdm(df.iterrows(), total=df.shape[0]):
    message = [
        {"role": "system", "content": "Please match these two products"},
        {"role": "user",
            "content": f" product 1: {row['title_left']}, product 2: {row['title_right']}"},
    ]
    error = ""
    for i in range(3):
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=message,
                max_tokens=3,
                temperature=0.0,
            )
            # if the above call succeeds, break out of the loop and continue
            break
        except Exception as e:
            error = e
            print(f"Error: {e}")
            # if the call fails, wait for one minute before retrying
            time.sleep(60)

    # check if the response was set successfully
    if response:
        # your code here
        df.at[index, 'chatbot_response_raw'] = response
        df.at[index, 'chatbot_response'] = response['choices'][0]['message']['content']
        df.at[index, 'chatbot_question'] = message
        print(index, response['choices'][0]['message']['content'])
    else:
        df.at[index, 'chatbot_response_raw'] = error
        df.at[index, 'chatbot_response'] = -1
        df.at[index, 'chatbot_question'] = message
        print("Error: response was not set successfully")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0 product 1: Maxxis Maxxis Minion DHR2 29 x 2.3 Folding Bead: Cycling Equipment, product 2: Maxxis Minion DHR II 3
# 1 product 1: Office Supplies, product 2: Office Supplies
# 2 product 1: Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266: Electronics
# product 2: CRUCIAL CT4
# 3 product 1: Crucial MX500 250GB 2.5" SATA III: Electronics
# product 2: JABARA Evolve 65 with Link 370 USB - Mono:
# 4 product 1: Intel Core I3 7th Gen 7100 3.90 Ghz; 2 Core 4 Thread; 3 Mb Smartcache; 51 W Tdp
# 5 Product 1: Tissot Seastar 1000 T120.417.11.051.00: Watches
# Product 2: Samsung Portable SSD T7 Touch MU-PC1
# 6 product 1: Samsung 970 EVO SSD M.2 2280 - 1TB SSD - 1 TB - M.2 2280 (80mm) - PCI Express
# 7 product 1: Ilford Ilford FP4+ 125 120 B&W Film - Single Roll: Photography
# product 2: Canon EF-S 18-200mm f3.5
# 8 product 1: iiyama 27' ETE, ULTRA SLIM LINE, 2560x1440 WQHD, IPS, 5ms, FreeSync, 13
# 9 product 1: Cycling Equipment, product 2: Cycling Equipment
# 10 product 1: Kingston Technology DataTraveler SE9 G2 64GB lecteur USB flash 64 Go USB Type-A 3.2 Gen 1 (3.1 Gen 1
# 11 product 1: Epson Tusz T7031 BLACK L do serii WorkForce WP4000/4500 (1.2k): Printer Accessories
# product 2: Epson Multip
# 12 product 1: Computer Hardware, product 2: Computer Hardware
# 13 product 1: TISSOT SEASTAR 1000 AUTOMATIC T120.407.11.051.00: Watches, product 2: Crucial Crucial SSD MX500
# 14 product 1: RAM Mount 9" Arm for 1.5" Ball: Electronics
# product 2: RAM-Mounts Long Double Socket Verbindungsarm RAM-201U-D
# 15 product 1: RAM-B-408-75-1-UN7U: Electronics, product 2: TP-LINK - AC1350 DUAL BAND WRLS ROUTER
# 16 product 1: Audio Technica Headphones ATH-M50XWH 3.5mm (1/8 inch), Headband/On-Ear, White: Electronics
# product 2:
# 17 product 1: AMD Ryzen™ 5 3400G with Radeon™ RX Vega 11 Graphics: Electronics
# product 2: AMD Ryzen 5 3400G 3.7
# 18 product 1: Computer Components, product 2: Computer Components
# 19 product 1: HydroFlask 32 oz. Wide Mouth Bottle w/ Flex Cap: Outdoors
# product 2: HydroFlask 21 oz. Standard Mouth Bottle w/ Flex Cap
# 20 product 1: SanDisk Cruzer Glide - USB flash drive - 64 GB: Electronics, product 2: Kingston Canvas Select UHS-I, 64 GB: Electronics
# 21 product 1: Garmin Fenix 6X Sapphire Carbon Grey DLC 010-02157-11: Electronics
# product 2: Garmin, Fenix 6X Pro & Sapphire Edition GPS
# 22 product 1: 3M - Privacy filter 23" widescreen: Computer Accessories, product 2: Fujifilm Fujinon XF 23/1,4: Camera Equipment
# 23 product 1: Epson Cartouche black L 1200 Pages WF 4015DN/4025/4525DNF (C13T70314010): Office Supplies, product
# 24 product 1: CANON PFI-107 ink cartridge cyan: Office Supplies
# product 2: Cartucho Canon PFI-107 C Cian: Office Supplies
# 25 product 1: Samsung UH46F5 UHF5 Series - 46" LED-display - Full HD: Electronics, product 2: RAM Double U-Bolt Base w/ 2
# 26 product 1: Corsair Vengeance LPX 8GB DDR4-3000 - DIMM: Electronics
# product 2: Corsair Vengeance LPX RAM 16GB 240
# 27 product 1: Jabra Evolve 20 monaural wired USB headset: Electronics
# product 2: JABRA - EVOLVE 20 UC MONO HD AUDIOIN ACCS:
# 28 product 1: Apple Airpods Pro with Wireless Charging Case: Electronics
# product 2: APPLE - AirPods 2 Med Wireless Charging Case: Electronics
# 29 product 1: Daniel Wellington Medium Rose Gold Black Canvas Watch DW00100150: Watches
# product 2: Daniel Wellington Cornwall Classic DW00100150: Watches
# 30 product 1: ASUS ROG STRIX X570-F GAMING (AM4) (D) (90MB1160-M0EAY0): Electronics
# product 2: Epson
# 31 product 1: ASUS GeForce GTX1660 DUAL EVO OC: Electronics
# product 2: ASUS VGA NVIDIA DUAL-GTX1660S-O6G-EVO, GTX 166
# 32 product 1: Electronics, product 2: Electronics
# 33 product 1: Electronics
# product 2: Electronics
# 34 product 1: Dymo D1 Tape for Electronic Labelmakers 24mmx7m Black on White Ref 53713 S0720930: Office Supplies, product 2: Tape
# 35 product 1: Logitech H540 USB Headset with Noise Cancelling Mic981 000480: Electronics
# product 2: HPE 300GB 6G SAS 10K rpm
# 36 product 1: Printer Accessories, product 2: Printer Accessories
# 37 product 1: Printer Accessories, product 2: Printer Accessories
# 38 product 1: Tissot T-Sport T1204071104101 Seastar watch: Watches, product 2: Switch T1700G-28TQ 24 porturi
# 39 product 1: Victron Energy MultiPlus Compact 12/2000/80-30 230V: Electronics
# product 2: Corsair ML Series ML140 PRO LED Premium Magnetic Lev
# 40 product 1: Computer Storage, product 2: Computer Storage
# 41 product 1: Trading Card Games, product 2: Trading Card Games
# 42 product 1: 4 Burner Blaze LTE Grill with Lights (32"): Outdoors
# product 2: Epson T7891 tinta negro original: Electronics
# 43 product 1: Cooler Master MasterLiquid Lite ML120L RGB V2: Computer Hardware
# product 2: COOLER MASTER MASTERLIQUID ML120L RGB CPU COOLER V2:
# 44 product 1: Logitech C922 Pro Stream Webcam (960-001090): Electronics
# product 2: Intel Core i7 10700 Core i7 3.8 GHz - Comet
# 45 product 1: SanDisk Extreme Pro USB 3.0 SD UHS-II Card Reader/Writer: Electronics
# product 2: SanDisk Extreme Pro 128 GB USB 3.0
# 46 product 1: Stationery, product 2: Stationery
# 47 product 1: Fujifilm Fujinon XF 23/1,4: Electronics
# product 2: Fujifilm FUJINON XF 23/2 R WR: Electronics
# 48 product 1: AF-S 24–85mm f/3.5–4.5G ED: Electronics, product 2: 0000071495| Nikon Nikkor AF-S
# 49 product 1: Maxxis Maxxis, High Roller II, Tire, 29''x2.50, Folding, Tubeless Ready, 3C Maxx Terra, Double Down, Wide
# 50 product 1: Apple AirPods with Charging Case (Latest Model): Electronics
# product 2: Apple AirPods with Charging Case - (Brand New): Electronics
# 51 product 1: GIGABYTE VGA NVIDIA GeForce GTX 1650 D6 OC 4G Rev. 2.0, 4GB GDDR6, 1xDVI,
# 52 product 1: Shimano Dura-Ace CS-R9100 Cassette 11 vitesses: Cycling Equipment, product 2: Shimano DURA ACE CN-HG900-11 HG
# 53 product 1: Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266: Computer Components, product 2: Gigabyte Radeon RX
# 54 product 1: ASUS GeForce RTX 2060 SUPER TURBO EVO: Electronics
# product 2: ASUS GeForce RTX 2080 SUPER DUAL EVO OC: Electronics
# 55 product 1: Watches, product 2: Watches
# 56 product 1: Tissot Mens T-Sport Seastar Black Watch T120.407.17.041.00: Watches, product 2: Switch T1700G-28
# 57 product 1: GARMIN Fenix 5X Sapphire Edition 51mm Black: Electronics
# product 2: Garmin Fenix 5 Multisport GPS Watch 47mm Case Slate Grey
# 58 product 1: Externe SSD Portable T7, 2 TB, Touch Black, USB 3.2 Gen 2: Electronics
# product 2: Samsung Portable SSD T7 Touch
# 59 product 1: Epson STYLUS PHOTO R3000 BLACK INK: Printer Accessories, product 2: Epson UltraChrome K3 T1571 Ink Cartridge - Photo Black:
# 60 product 1: Evans - EC2S Clear Tom Batter, 13": Musical Instruments
# product 2: Evans EC2 SST Clear Batter Drumhead 14 in.: Musical Instruments
# 61 product 1: Blaze Professional Grill Cart for 34-Inch 3-Burner Gas Grill: Outdoor Cooking Equipment, product 2: Blaze 3 Burner Pro Cart Only: Outdoor Cooking
# 62 product 1: Cooler Master Hyper H411R Tower CPU Cooler: Computer Components, product 2: Cooler Master Mastercase H500 ARGB: Computer Components
# 63 product 1: SIGMA 105mm f/1.4 DG HSM Art Lens for Canon EF: Camera Lenses
# product 2: Canon EF-M 18-150mm,
# 64 product 1: Fujifilm Instax Square Film Black Frame 10 Shots: Photography Accessories, product 2: Epson Premium Glossy Photo Paper - 30 Sheets: Office Supplies
# 65 product 1: Printer Accessories, product 2: Printer Accessories
# 66 product 1: RAM Short Double Socket Arm C Size (RAM-201U-B): Electronics
# product 2: Double Socket Arm - Long - RAM-B-201U-C: Electronics
# 67 product 1: D'Addario Acoustic String Set, Phosphor Bronze, EJ16 Light .012-.053: Musical Instruments
# product 2: Daddario 12-
# 68 product 1: Tissot T-Touch Expert Solar Men's Watch T091.420.46.051.01: Watches
# product 2: Tissot Mens T-Touch Expert
# 69 product 1: Cooler Master Hyper H411R Tower CPU Cooler: Computer Hardware, product 2: Cooler Master CPU Cooler Hyper H411R: Computer Hardware
# 70 product 1: Samsung CF390 27" 4ms HDMI Curved Monitor: Electronics
# product 2: Monitor curbat LED SAMSUNG C27F390FHU, 27
# 71 product 1: Watches, product 2: Watches
# 72 product 1: Computer Accessories, product 2: Computer Accessories
# 73 product 1: ASUS ROG Strix B550-F Gaming B550 - Motherboard - AMD Socket AM4 (Ryzen) (90MB14S0-M0EAY0):
# 74 product 1: Crucial BX500 2.5" 480GB SATA III Solid State Drive: Electronics
# product 2: Crucial 480GB BX500 int 2.5
# 75 product 1: Western Digital Externý disk 2.5" My Passport 1TB USB 3.0: Electronics
# product 2: UBIQUITI UNIFI IR LED
# 76 product 1: JABRA EVOLVE 40 UC Mono USB Corded Headset with 3.5mm Jack - Over-the-head - Supra-aural - Unified Communications: Electronics
# 77 product 1: Shimano PD-R550 SPD-SL PEDALS BLACK: Cycling Equipment, product 2: PEDAL, PD-RS500, SPD-SL, W/CLEAT:
# 78 product 1: MAXXIS Pneu Maxxis Assegai 3C MaxxTerra EXO+ TR: Cycling Equipment, product 2: Maxxis Assegai WT
# 79 product 1: Sony SEL-70200G F4 OSS: Electronics
# product 2: 106R01634 Toner black pentru Phaser 6000, 6010, WorkCentre
# 80 product 1: BenQ SW2700PT 27" 2KPhotoVue Photographer Monitor: Electronics
# product 2: Benq SW2700PT 27 ", IPS, QHD
# 81 product 1: Original EPSON S050189 Toner Cyan: Office Supplies, product 2: Originln toner EPSON C13S050189 (Azurov): Office Supplies
# 82 product 1: Crucial BX500 2.5" 120 GB Serial ATA III: Electronics
# product 2: Crucial MX500 250GB 2.5" SATA III
# 83 product 1: Kingston Value RAM 4GB 1600MHz PC3-12800 DDR3 Non-ECC CL11 DIMM SR x8 Desktop Memory KVR16N11S8
# 84 product 1: Cooler Master Chassis, MasterBox Lite 5 Tower: Computer Hardware
# product 2: HP Color LaserJet Professional CP5225dn Duplex Colour Laser Printer - A3
# 85 product 1: Canon CNM6448B001-6448B001 CLI-251XL ChromaLife100 High-Yield Ink: Office Supplies
# product 2: Genuine Epson C
# 86 product 1: Apple In-Ear Wireless Airpods with Charging Case - White-MV7N2ZM/A: Electronics
# product 2: Bosch KGN34NWEAG
# 87 product 1: GARMIN Fenix 5X Sapphire Edition 51mm Black: Electronics
# product 2: Garmin Black fenix 5S Sapphire Watch with Black Band: Electronics
# 88 product 1: APC Smart-UPS 1000VA LCD RM: Electronics
# product 2: APC Smart-UPS SRT 10000VA 230V: Electronics
# 89 product 1: WD Red 2.5 1TB IntelliPower SATA 6Gb/s 9.5mm 16MB Cache 3 Years Warranty: Electronics
# product 2:
# 90 product 1: Electronics, product 2: Electronics
# 91 product 1: Replacement Battery 140 FD Onl: Electronics
# product 2: APC Replacement battery cartridge #140 (REP. RBC44) (APCRBC140): Electronics
# 92 product 1: Photography Equipment, product 2: Photography Equipment
# 93 product 1: Western Digital Blue PC SSD 250GB: Electronics
# product 2: WD Blue 250GB PC SSD - SATA 6 Gb/s 2.5 Inch Solid State
# 94 product 1: APC Smart-UPS 1000VA/700W, Line-Interactive, LCD, 8x C13, SmartSlot, USB, HS repl. batt. (S
# 95 product 1: Ryze Tello Battery Charging Hub G1CH: Electronics, product 2: AirPods with Wireless Charging Case: Electronics
# 96 product 1: 2MP 25X Network IR PTZ Camera: Electronics
# product 2: HIKVISION 2MP 25X NETWORK IR SPEED DOME CAMERA DS-2
# 97 product 1: Canon EF-S 18-135mm f/3.5-5.6 IS USM Zoom Lens: Electronics
# product 2: Nikon Nikkor AF-S 24
# 98 product 1: Cooler Master Chassis, MasterBox Lite 5 Tower: Computer Hardware
# product 2: CASE MID-TOWER NO PSU MASTERBOX LITE 5 3USB3 BLACK
# 99 product 1: Crucial BX500 120GB 2.5″ SSD: Electronics
# product 2: Crucial Crucial SSD MX500 500GB M.2 2280

# %%
df.head()
# Out:
#     id_left brand_left  \
# 0  70108616     Maxxis
# 1  67977820        NaN
# 2  79859336    Crucial
# 3  30368884        NaN
# 4  82078171        NaN
#
#                                                                                           title_left  \
# 0                                                    Maxxis Maxxis Minion DHR2 29 x 2.3 Folding Bead
# 1                                    Canon CLI251XL High Yield Black Inkjet Cartridge Remanufactured
# 2                                       Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266
# 3                                                                  Crucial MX500 250GB 2.5" SATA III
# 4  Intel Core I3 7th Gen 7100 3.90 Ghz; 2 Core 4 Thread; 3 Mb Smartcache; 51 W Tdp; Lga 1151 S R35 C
#
#                                                                                                                                                                                                                                                                                               description_left  \
# 0                                                                                                                                                                                                                                              The new incarnation of the Minion DHR. Ready to shred any line.
# 1  Crazy Inkjets is a leading supplier of high quality printing supplies for your Canon CLI251XL printer cartridge. CrazyInkjets products are guaranteed to meet or exceed the quality, reliability and yield standards of the original equipment remanufacturer. The units are tested to ensure compliance...
# 2                                                                                                                                                                                                                                                                                                          NaN
# 3                                                                                                                                                                                                                                       MX500 250GB SATA 2.5-inch, SATA 6.0Gb/s, 560 MB/s Read, 510 MB/s Write
# 4  ntel i3-7100, Core. Processor family: 7th gen Intel® Core™ i3, Processor frequency: 3.9 GHz, Processor socket: LGA 1151 (Socket H4). Memory channels: Dual, Maximum internal memory supported by processor: 64 GB, Memory types supported by processor: DDR3L-SDRAM,DDR4-SDRAM. On-board graphics adapte...
#
#   price_left priceCurrency_left  specTableContent_left  cluster_id_left  \
# 0     110.00                CAD                    NaN          1084991
# 1       6.95                USD                    NaN           767463
# 2      34.99                CAD                    NaN          1892167
# 3      43.59                EUR                    NaN           672125
# 4    2.899E3                ZAR                    NaN           443612
#
#    id_right      brand_right  ...            pair_id label is_hard_negative  \
# 0  45040021           Maxxis  ...  70108616#45040021     1            False
# 1  69787972          Samsung  ...  67977820#69787972     0             True
# 2  65646040          Crucial  ...  79859336#65646040     1            False
# 3  86893846              NaN  ...  30368884#86893846     0            False
# 4   6914049  WESTERN DIGITAL  ...   82078171#6914049     0            False
#
#              roberta-base_logits  roberta-base_prediction  \
# 0  [-4.3633804321, 4.6556377411]                        1
# 1  [3.8366084099, -4.2942962646]                        0
# 2   [-4.363576889, 4.6508393288]                        1
# 3  [3.8347194195, -4.2961273193]                        0
# 4  [3.8386721611, -4.3010449409]                        0
#
#    rsupcon-base_logits rsupcon-base_prediction  \
# 0                [1.0]                       1
# 1                [0.0]                       0
# 2                [1.0]                       1
# 3                [0.0]                       0
# 4                [0.0]                       0
#
#                                                                                                    chatbot_response  \
# 0  product 1: Maxxis Maxxis Minion DHR2 29 x 2.3 Folding Bead: Cycling Equipment, product 2: Maxxis Minion DHR II 3
# 1                                                            product 1: Office Supplies, product 2: Office Supplies
# 2      product 1: Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266: Electronics\nproduct 2: CRUCIAL CT4
# 3  product 1: Crucial MX500 250GB 2.5" SATA III: Electronics\nproduct 2: JABARA Evolve 65 with Link 370 USB - Mono:
# 4                        product 1: Intel Core I3 7th Gen 7100 3.90 Ghz; 2 Core 4 Thread; 3 Mb Smartcache; 51 W Tdp
#
#                                                                                                                                                                                                                                                                                           chatbot_response_raw  \
# 0  {'id': 'chatcmpl-7a2PJXD30RMVmVvOJrSzcqSRJ5ouz', 'object': 'chat.completion', 'created': 1688823417, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Maxxis Maxxis Minion DHR2 29 x 2.3 Folding Bead: Cycling Equipment, product 2: Maxxis Minion DHR II 3",
#   "ro...
# 1  {'id': 'chatcmpl-7a2PNNQOnhJRFKKMVzuqggncuJGVG', 'object': 'chat.completion', 'created': 1688823421, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Office Supplies, product 2: Office Supplies",
#   "role": "assistant"
# }, 'finish_reason': 'stop'}], 'usage': {'...
# 2  {'id': 'chatcmpl-7a2POoegCmNDoLsZag4KOIztZj4mg', 'object': 'chat.completion', 'created': 1688823422, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266: Electronics\nproduct 2: CRUCIAL CT4",
#   "role":...
# 3  {'id': 'chatcmpl-7a2PSC2hJ9ojRg1tvYYBagWh0Fcuh', 'object': 'chat.completion', 'created': 1688823426, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Crucial MX500 250GB 2.5\" SATA III: Electronics\nproduct 2: JABARA Evolve 65 with Link 370 USB - Mono:",
#   "r...
# 4  {'id': 'chatcmpl-7a2PVnttBxPEhBOnQ6toIGkXLEg1y', 'object': 'chat.completion', 'created': 1688823429, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Intel Core I3 7th Gen 7100 3.90 Ghz; 2 Core 4 Thread; 3 Mb Smartcache; 51 W Tdp",
#   "role": "assistant"
# }, 'f...
#
#                                                                                                                                                                                                                                                                                               chatbot_question
# 0  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 1  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 2  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 3  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 4  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
#
# [5 rows x 26 columns]

# %%
# get the number of rows were the chatbot respionse is not empty
df[df['chatbot_response'] != ''].shape
# Out:
# (100, 26)

# %%
df.tail()
# Out:
#      id_left brand_left                                      title_left  \
# 95  53525303       Ryze            Ryze Tello Battery Charging Hub G1CH
# 96  81415527        NaN                   2MP 25X Network IR PTZ Camera
# 97  53053823        NaN  Canon EF-S 18-135mm f/3.5-5.6 IS USM Zoom Lens
# 98  72039756        NaN   Cooler Master Chassis, MasterBox Lite 5 Tower
# 99  79205401        NaN                    Crucial BX500 120GB 2.5″ SSD
#
#                                                                                                                                                                                                                                                                                                description_left  \
# 95                                                                                                                                                                                                                                                                                                          NaN
# 96  1/2.8\" progressive scan CMOSUp to 1920 × 1080@30fps resolutionMin. illumination: Color: 0.005 Lux @(F1.6, AGC ON) B/W: 0.001 Lux @(F1.6, AGC ON) 0 Lux with IR25× optical zoom, 16× digital zoomWDR, HLC, BLC, 3D DNR, Defog, EIS, Regional Exposure, Regional FocusUp to 150 m IR distance24 VAC & Hi-...
# 97  The Canon EF-S 18-135mm f/3.5-5.6 IS USM Zoom Lens is great for photos and movies. With improved Image Stabilisation, it allows hand held shooting even in lower light conditions.Features 16 elements from 12 groups18-135mm Focal LengthBuilt-in Image StabiliserNano USM technologyMaximum magnificat...
# 98                                                                                                                                                                                                                                                                                                          NaN
# 99  Ever wonder why your phone responds faster than your computer? It’s because your phone runs on flash memory. Add flash memory to your laptop or desktop computer with the Crucial BX500 120GB 2.5″ SSD, the easiest way to get all the speed of a new computer without the price. This SSD offers sequen...
#
#             price_left priceCurrency_left  specTableContent_left  \
# 95                 129                DKK                    NaN
# 96  Incl. BTW€1.035,76                EUR                    NaN
# 97                 799                AUD                    NaN
# 98               64.52                USD                    NaN
# 99               499.0                ZAR                    NaN
#
#     cluster_id_left  id_right brand_right  ...            pair_id label  \
# 95          1555405  79449686         NaN  ...  53525303#79449686     0
# 96          2694265  46810114         NaN  ...  81415527#46810114     1
# 97           390091  45511817         NaN  ...  53053823#45511817     0
# 98          1006147  43470746         NaN  ...  72039756#43470746     1
# 99           744155  31394689     Crucial  ...  79205401#31394689     0
#
#    is_hard_negative                  roberta-base_logits  \
# 95             True  [3.6632392406000003, -4.1180138588]
# 96            False        [-4.1793274879, 4.4736194611]
# 97             True        [3.7480974197, -4.2194314003]
# 98            False        [-4.3535614014, 4.6426811218]
# 99             True  [3.8113934994000003, -4.2730379105]
#
#     roberta-base_prediction  rsupcon-base_logits rsupcon-base_prediction  \
# 95                        0                [0.0]                       0
# 96                        1                [1.0]                       1
# 97                        0                [0.0]                       0
# 98                        1                [1.0]                       1
# 99                        0                [0.0]                       0
#
#                                                                                                                               chatbot_response  \
# 95                   product 1: Ryze Tello Battery Charging Hub G1CH: Electronics, product 2: AirPods with Wireless Charging Case: Electronics
# 96                       product 1: 2MP 25X Network IR PTZ Camera: Electronics\nproduct 2: HIKVISION 2MP 25X NETWORK IR SPEED DOME CAMERA DS-2
# 97                                     product 1: Canon EF-S 18-135mm f/3.5-5.6 IS USM Zoom Lens: Electronics\nproduct 2: Nikon Nikkor AF-S 24
# 98  product 1: Cooler Master Chassis, MasterBox Lite 5 Tower: Computer Hardware\nproduct 2: CASE MID-TOWER NO PSU MASTERBOX LITE 5 3USB3 BLACK
# 99                                   product 1: Crucial BX500 120GB 2.5″ SSD: Electronics\nproduct 2: Crucial Crucial SSD MX500 500GB M.2 2280
#
#                                                                                                                                                                                                                                                                                            chatbot_response_raw  \
# 95  {'id': 'chatcmpl-7a2U4IyKM563DbZAJkfvcy2LMdScH', 'object': 'chat.completion', 'created': 1688823712, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Ryze Tello Battery Charging Hub G1CH: Electronics, product 2: AirPods with Wireless Charging Case: Electronic...
# 96  {'id': 'chatcmpl-7a2U7eSkdNrFqE25zBYz9zzBAxjJu', 'object': 'chat.completion', 'created': 1688823715, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: 2MP 25X Network IR PTZ Camera: Electronics\nproduct 2: HIKVISION 2MP 25X NETWORK IR SPEED DOME CAMERA DS-2",
# ...
# 97  {'id': 'chatcmpl-7a2UAdB9lNQJjjIT15dxMykW1DHn6', 'object': 'chat.completion', 'created': 1688823718, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Canon EF-S 18-135mm f/3.5-5.6 IS USM Zoom Lens: Electronics\nproduct 2: Nikon Nikkor AF-S 24",
#   "role": "ass...
# 98  {'id': 'chatcmpl-7a2UEQFZQ5peIqDXOWceYq1w3g06j', 'object': 'chat.completion', 'created': 1688823722, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Cooler Master Chassis, MasterBox Lite 5 Tower: Computer Hardware\nproduct 2: CASE MID-TOWER NO PSU MASTERBOX ...
# 99  {'id': 'chatcmpl-7a2UHbSgeB781qspK8V2c7sTL4clA', 'object': 'chat.completion', 'created': 1688823725, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Crucial BX500 120GB 2.5\u2033 SSD: Electronics\nproduct 2: Crucial Crucial SSD MX500 500GB M.2 2280",
#   "role...
#
#                                                                                                                                                                                                                                                                                                chatbot_question
# 95  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 96  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 97  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 98  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 99  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
#
# [5 rows x 26 columns]

# %%
def clean_response(response):
    if "yes" in response.lower():
        return 1
    elif "no" in response.lower():
        return 0
    else:
        return -1

# %%
# add a coloumn with a clean version of the chatbot response if the chatresponse contains Yes/yes it will be 1 else if it contains No/no it will be 0 if it is 0 or 1 
df['chatbot_response_clean'] = df['chatbot_response'].apply(lambda x: clean_response(x))

# %%
# get the current date and time
now = datetime.now()

# save the dataframe as a json file
df.to_json(f'data/results/chat_gpt/medium/{now}_simple_promt_all.json')

# %%
# look at the wrong answers
df[df['chatbot_response_clean'] != df['label']].head()
# Out:
#     id_left brand_left  \
# 0  70108616     Maxxis
# 1  67977820        NaN
# 2  79859336    Crucial
# 3  30368884        NaN
# 4  82078171        NaN
#
#                                                                                           title_left  \
# 0                                                    Maxxis Maxxis Minion DHR2 29 x 2.3 Folding Bead
# 1                                    Canon CLI251XL High Yield Black Inkjet Cartridge Remanufactured
# 2                                       Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266
# 3                                                                  Crucial MX500 250GB 2.5" SATA III
# 4  Intel Core I3 7th Gen 7100 3.90 Ghz; 2 Core 4 Thread; 3 Mb Smartcache; 51 W Tdp; Lga 1151 S R35 C
#
#                                                                                                                                                                                                                                                                                               description_left  \
# 0                                                                                                                                                                                                                                              The new incarnation of the Minion DHR. Ready to shred any line.
# 1  Crazy Inkjets is a leading supplier of high quality printing supplies for your Canon CLI251XL printer cartridge. CrazyInkjets products are guaranteed to meet or exceed the quality, reliability and yield standards of the original equipment remanufacturer. The units are tested to ensure compliance...
# 2                                                                                                                                                                                                                                                                                                          NaN
# 3                                                                                                                                                                                                                                       MX500 250GB SATA 2.5-inch, SATA 6.0Gb/s, 560 MB/s Read, 510 MB/s Write
# 4  ntel i3-7100, Core. Processor family: 7th gen Intel® Core™ i3, Processor frequency: 3.9 GHz, Processor socket: LGA 1151 (Socket H4). Memory channels: Dual, Maximum internal memory supported by processor: 64 GB, Memory types supported by processor: DDR3L-SDRAM,DDR4-SDRAM. On-board graphics adapte...
#
#   price_left priceCurrency_left  specTableContent_left  cluster_id_left  \
# 0     110.00                CAD                    NaN          1084991
# 1       6.95                USD                    NaN           767463
# 2      34.99                CAD                    NaN          1892167
# 3      43.59                EUR                    NaN           672125
# 4    2.899E3                ZAR                    NaN           443612
#
#    id_right      brand_right  ... label is_hard_negative  \
# 0  45040021           Maxxis  ...     1            False
# 1  69787972          Samsung  ...     0             True
# 2  65646040          Crucial  ...     1            False
# 3  86893846              NaN  ...     0            False
# 4   6914049  WESTERN DIGITAL  ...     0            False
#
#              roberta-base_logits roberta-base_prediction  rsupcon-base_logits  \
# 0  [-4.3633804321, 4.6556377411]                       1                [1.0]
# 1  [3.8366084099, -4.2942962646]                       0                [0.0]
# 2   [-4.363576889, 4.6508393288]                       1                [1.0]
# 3  [3.8347194195, -4.2961273193]                       0                [0.0]
# 4  [3.8386721611, -4.3010449409]                       0                [0.0]
#
#    rsupcon-base_prediction  \
# 0                        1
# 1                        0
# 2                        1
# 3                        0
# 4                        0
#
#                                                                                                    chatbot_response  \
# 0  product 1: Maxxis Maxxis Minion DHR2 29 x 2.3 Folding Bead: Cycling Equipment, product 2: Maxxis Minion DHR II 3
# 1                                                            product 1: Office Supplies, product 2: Office Supplies
# 2      product 1: Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266: Electronics\nproduct 2: CRUCIAL CT4
# 3  product 1: Crucial MX500 250GB 2.5" SATA III: Electronics\nproduct 2: JABARA Evolve 65 with Link 370 USB - Mono:
# 4                        product 1: Intel Core I3 7th Gen 7100 3.90 Ghz; 2 Core 4 Thread; 3 Mb Smartcache; 51 W Tdp
#
#                                                                                                                                                                                                                                                                                           chatbot_response_raw  \
# 0  {'id': 'chatcmpl-7a2PJXD30RMVmVvOJrSzcqSRJ5ouz', 'object': 'chat.completion', 'created': 1688823417, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Maxxis Maxxis Minion DHR2 29 x 2.3 Folding Bead: Cycling Equipment, product 2: Maxxis Minion DHR II 3",
#   "ro...
# 1  {'id': 'chatcmpl-7a2PNNQOnhJRFKKMVzuqggncuJGVG', 'object': 'chat.completion', 'created': 1688823421, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Office Supplies, product 2: Office Supplies",
#   "role": "assistant"
# }, 'finish_reason': 'stop'}], 'usage': {'...
# 2  {'id': 'chatcmpl-7a2POoegCmNDoLsZag4KOIztZj4mg', 'object': 'chat.completion', 'created': 1688823422, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266: Electronics\nproduct 2: CRUCIAL CT4",
#   "role":...
# 3  {'id': 'chatcmpl-7a2PSC2hJ9ojRg1tvYYBagWh0Fcuh', 'object': 'chat.completion', 'created': 1688823426, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Crucial MX500 250GB 2.5\" SATA III: Electronics\nproduct 2: JABARA Evolve 65 with Link 370 USB - Mono:",
#   "r...
# 4  {'id': 'chatcmpl-7a2PVnttBxPEhBOnQ6toIGkXLEg1y', 'object': 'chat.completion', 'created': 1688823429, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Intel Core I3 7th Gen 7100 3.90 Ghz; 2 Core 4 Thread; 3 Mb Smartcache; 51 W Tdp",
#   "role": "assistant"
# }, 'f...
#
#                                                                                                                                                                                                                                                                                               chatbot_question  \
# 0  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 1  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 2  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 3  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
# 4  [{'role': 'system', 'content': 'You are a helpful assistant that assigns products to product categories. Please provide them in this format: product 1: category product 2: category They should be at a high level so things like electronics, outdoors etc.'}, {'role': 'user', 'content': ' product 1...
#
#   chatbot_response_clean
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
#
# [5 rows x 27 columns]

# %%
# Check the accuracy of the chatbot 
df[df['chatbot_response_clean'] == df['label']].shape[0]
print(f"Accuracy: {df[df['chatbot_response_clean'] == df['label']].shape[0] / df.shape[0]}")
# Out:
# Accuracy: 0.0

# %%
# Check the number of -1 responses
df[df['chatbot_response_clean'] == -1].shape[0]
# Out:
# 0

# %%
# Look at 5 complete chatbot responses dont limit the output length
# set the max_rows and max_columns options to None
# set the max_colwidth option to None
pd.set_option('display.max_colwidth', 300)

# display the first 5 chatbot responses where chatbot_response_raw is not -1
df['chatbot_response_raw'].head(3)
# Out:
# 0    {'id': 'chatcmpl-7a2PJXD30RMVmVvOJrSzcqSRJ5ouz', 'object': 'chat.completion', 'created': 1688823417, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Maxxis Maxxis Minion DHR2 29 x 2.3 Folding Bead: Cycling Equipment, product 2: Maxxis Minion DHR II 3",
#   "ro...
# 1    {'id': 'chatcmpl-7a2PNNQOnhJRFKKMVzuqggncuJGVG', 'object': 'chat.completion', 'created': 1688823421, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Office Supplies, product 2: Office Supplies",
#   "role": "assistant"
# }, 'finish_reason': 'stop'}], 'usage': {'...
# 2    {'id': 'chatcmpl-7a2POoegCmNDoLsZag4KOIztZj4mg', 'object': 'chat.completion', 'created': 1688823422, 'model': 'gpt-4-0613', 'choices': [{'index': 0, 'message': {
#   "content": "product 1: Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266: Electronics\nproduct 2: CRUCIAL CT4",
#   "role":...
# Name: chatbot_response_raw, dtype: object

# %%
# Lets look at all mistakes only show the title_left, title_right, label and chatbot_response_clean
df[df['chatbot_response_clean'] != df['label']][['title_left', 'title_right', 'label', 'chatbot_response_clean']]
# Out:
#                                                                                            title_left  \
# 0                                                     Maxxis Maxxis Minion DHR2 29 x 2.3 Folding Bead
# 1                                     Canon CLI251XL High Yield Black Inkjet Cartridge Remanufactured
# 2                                        Crucial Crucial Memory 4GB DDR4 2666 Unbuffered CT4G4SFS8266
# 3                                                                   Crucial MX500 250GB 2.5" SATA III
# 4   Intel Core I3 7th Gen 7100 3.90 Ghz; 2 Core 4 Thread; 3 Mb Smartcache; 51 W Tdp; Lga 1151 S R35 C
# ..                                                                                                ...
# 95                                                               Ryze Tello Battery Charging Hub G1CH
# 96                                                                      2MP 25X Network IR PTZ Camera
# 97                                                     Canon EF-S 18-135mm f/3.5-5.6 IS USM Zoom Lens
# 98                                                      Cooler Master Chassis, MasterBox Lite 5 Tower
# 99                                                                       Crucial BX500 120GB 2.5″ SSD
#
#                                                                                                                    title_right  \
# 0                                                Maxxis Minion DHR II 3C MaxxTerra/DD TR 29\" Tire - 29 x 2.3\" (Folding Bead)
# 1   Samsung MLT-D103L, High Yield Black Toner/Drum for ML-2950ND / 2955ND / 2955DW, SCX-4728FD / 4729FD / 4729FW (2,500 pages)
# 2                                              CRUCIAL CT4G4SFS8266 4Gb 2666Mhz DDR4 Notebook RAM SODIMM CL19 1.2V (By Micron)
# 3                                                                                    JABARA Evolve 65 with Link 370 USB - Mono
# 4                                                                                  DISCO DURO 2.5SSD 1TB SATA3 WD BLUE 3D NAND
# ..                                                                                                                         ...
# 95                                                                                         AirPods with Wireless Charging Case
# 96                                                              HIKVISION 2MP 25X NETWORK IR SPEED DOME CAMERA DS-2DE5225IW-AE
# 97                                                                 0000071495| Nikon Nikkor AF-S 24-85mm f/3.5-4.5G ED VR Lens
# 98                                                             CASE MID-TOWER NO PSU MASTERBOX LITE 5 3USB3 BLACK WINDOW PANEL
# 99                                                            Crucial Crucial SSD MX500 500GB M.2 2280 SATA 3.0 CT500MX500SSD4
#
#     label chatbot_response_clean
# 0       1                   None
# 1       0                   None
# 2       1                   None
# 3       0                   None
# 4       0                   None
# ..    ...                    ...
# 95      0                   None
# 96      1                   None
# 97      0                   None
# 98      1                   None
# 99      0                   None
#
# [100 rows x 4 columns]

# %%
# how many currencies are there in the dataset
df['priceCurrency_left'].unique()
# Out:
# array(['CAD', 'USD', 'EUR', 'ZAR', 'DKK', 'GBP', nan, 'AED', 'MYR', 'AUD',
#        'PLN', 'KYD', 'NOK', 'CZK', 'INR', 'HRK', 'SEK', 'CHF', 'NZD',
#        'RUB'], dtype=object)

# %%
# How often does priceCurrency_left and priceCurrency_right match
df[df['priceCurrency_left'] == df['priceCurrency_right']].shape[0]
# Out:
# 13
