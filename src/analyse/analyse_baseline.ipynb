# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import helper as analytics

# %%
prompt_order = [
    "domain-complex-force (Product)",
    "domain-complex-free (Product)",
    "domain-simple-force (Product)",
    "domain-simple-free (Product)",
    "general-complex-force",
    "general-complex-free",
    "general-simple-force",
    "general-simple-free",
    "Narayan-complex",
    "Narayan-simple",
]

# %% [markdown]
# ## ABT-BUY

# %%
df_abt_7b = pd.read_json("../results/baseline/abt-buy/2024-05-21-23-36-08_7b_all.json")
df_abt_13b = pd.read_json("../results/baseline/abt-buy/2024-03-10 10:31:34.028854_13b_all.json")
df_abt_70b = pd.read_json("../results/baseline/abt-buy/2024-03-10 20:29:20.858142_70b_all.json")
df_abt_turbo_0125 = pd.read_json("../results/baseline/abt-buy/2024-05-21-11-29-37_turbo_0125_abt_complete.json")

# drop tasks that are not in prompt_order
df_abt_7b = df_abt_7b[df_abt_7b["task"].isin(prompt_order)]
df_abt_13b = df_abt_13b[df_abt_13b["task"].isin(prompt_order)]
df_abt_70b = df_abt_70b[df_abt_70b["task"].isin(prompt_order)]
df_abt_turbo_0125 = df_abt_turbo_0125[df_abt_turbo_0125["task"].isin(prompt_order)]

# %%
analytics.draw_scores(df_abt_7b, prompt_order)
# Out:
# /Users/aaronsteiner/Documents/GitHub/master-thesis/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.796020     30.51      36.49   26.21
# 4   domain-complex-free (Product)  0.728027     45.51      34.60   66.50
# 7   domain-simple-force (Product)  0.825041      0.94      14.29    0.49
# 5    domain-simple-free (Product)  0.828358      0.96      33.33    0.49
# 2           general-complex-force  0.656716     34.91      25.81   53.88
# 0            general-complex-free  0.491708     38.27      24.14   92.23
# 3            general-simple-force  0.829187      0.00       0.00    0.00
# ...

# %%
analytics.draw_scores(df_abt_13b, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.664179     49.69      33.39   97.09
# 4   domain-complex-free (Product)  0.865672     65.82      58.21   75.73
# 7   domain-simple-force (Product)  0.880597     61.08      68.90   54.85
# 5    domain-simple-free (Product)  0.830017      0.97     100.00    0.49
# 2           general-complex-force  0.718076     54.18      37.50   97.57
# 0            general-complex-free  0.851575     63.09      54.84   74.27
# 3            general-simple-force  0.844113     56.88      53.91   60.19
# 1             general-simple-free  0.833333      5.63      85.71    2.91
# 8                 Narayan-complex  0.864013     45.99      92.65   30.58
# 9                  Narayan-simple  0.882255     47.41     100.00   31.07
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...

# %%
analytics.draw_scores(df_abt_70b, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.890547     74.81      61.64   95.15
# 4   domain-complex-free (Product)  0.833333     66.78      50.63   98.06
# 7   domain-simple-force (Product)  0.875622     44.03      95.16   28.64
# 5    domain-simple-free (Product)  0.877280     43.94     100.00   28.16
# 2           general-complex-force  0.922886     79.47      72.87   87.38
# 0            general-complex-free  0.791874     61.68      44.99   98.06
# 3            general-simple-force  0.896352     57.63      95.51   41.26
# 1             general-simple-free  0.895522     57.14      95.45   40.78
# 8                 Narayan-complex  0.915423     72.93      88.28   62.14
# 9                  Narayan-simple  0.941128     80.22      94.12   69.90
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...

# %%
analytics.draw_scores(df_abt_turbo_0125, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.913765     78.95      67.71   94.66
# 4   domain-complex-free (Product)  0.836650     67.44      51.13   99.03
# 7   domain-simple-force (Product)  0.952736     85.27      91.16   80.10
# 5    domain-simple-free (Product)  0.941128     84.60      76.47   94.66
# 2           general-complex-force  0.928690     81.62      72.90   92.72
# 0            general-complex-free  0.807629     63.86      47.02   99.51
# 3            general-simple-force  0.942786     81.10      93.08   71.84
# 1             general-simple-free  0.959370     88.74      84.28   93.69
# 8                 Narayan-complex  0.959370     87.78      90.26   85.44
# 9                  Narayan-simple  0.959370     86.93      96.45   79.13
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...

# %% [markdown]
# ## Amazon-Google

# %%
df_ag_7b = pd.read_json("../results/baseline/amazon-google/2024-03-06-16:48:59_7b_all.json")
df_ag_13b = pd.read_json("../results/baseline/amazon-google/2024-03-08 19:01:19.825925_13b_all.json")
df_ag_70b = pd.read_json("../results/baseline/amazon-google/2024-03-09 15:51:35.917303_70b_all.json")
df_ag_turbo_0125 = pd.read_json("../results/baseline/amazon-google/2024-05-20-17-13-55_turbo0125_ag_all.json")

# drop tasks that are not in prompt_order
df_ag_7b = df_ag_7b[df_ag_7b["task"].isin(prompt_order)]
df_ag_13b = df_ag_13b[df_ag_13b["task"].isin(prompt_order)]
df_ag_70b = df_ag_70b[df_ag_70b["task"].isin(prompt_order)]
df_ag_turbo_0125 = df_ag_turbo_0125[df_ag_turbo_0125["task"].isin(prompt_order)]

# %%
analytics.draw_scores(df_ag_7b, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.622366     31.67      24.11   46.15
# 4   domain-complex-free (Product)  0.569692     37.31      25.77   67.52
# 7   domain-simple-force (Product)  0.807131     11.19      44.12    6.41
# 5    domain-simple-free (Product)  0.811994      7.20      56.25    3.85
# 2           general-complex-force  0.395462     30.28      19.38   69.23
# 0            general-complex-free  0.367909     33.48      20.92   83.76
# 3            general-simple-force  0.809562      9.27      48.00    5.13
# 1             general-simple-free  0.803890      9.02      37.50    5.13
# 8                 Narayan-complex  0.808752      0.00       0.00    0.00
# 9                  Narayan-simple  0.817666     16.36      62.86    9.40
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 1
# ...

# %%
analytics.draw_scores(df_ag_13b, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.496759     41.80      26.77   95.30
# 4   domain-complex-free (Product)  0.753647     34.48      34.78   34.19
# 7   domain-simple-force (Product)  0.716370     41.08      33.89   52.14
# 5    domain-simple-free (Product)  0.811994      4.13      62.50    2.14
# 2           general-complex-force  0.444084     40.24      25.27   98.72
# 0            general-complex-free  0.718801     35.14      31.23   40.17
# 3            general-simple-force  0.669368     41.55      31.25   61.97
# 1             general-simple-free  0.806321      6.27      38.10    3.42
# 8                 Narayan-complex  0.803890      7.38      90.00    3.85
# 9                  Narayan-simple  0.819287      9.72      92.31    5.13
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...

# %%
analytics.draw_scores(df_ag_70b, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.819287     51.63      52.42   50.85
# 4   domain-complex-free (Product)  0.744733     55.36      42.47   79.49
# 7   domain-simple-force (Product)  0.811994     10.08      54.17    5.56
# 5    domain-simple-free (Product)  0.811994      6.45      57.14    3.42
# 2           general-complex-force  0.813614     31.14      52.00   22.22
# 0            general-complex-free  0.713128     53.17      38.51   85.90
# 3            general-simple-force  0.805511     11.11      41.67    6.41
# 1             general-simple-free  0.811183     10.04      52.00    5.56
# 8                 Narayan-complex  0.825770     36.90      60.78   26.50
# 9                  Narayan-simple  0.836305     42.61      63.56   32.05
#
#    Num -1 Responses
# 6                 0
# 4                25
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...

# %%
analytics.draw_scores(df_ag_turbo_0125, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.747974     57.57      42.28   90.17
# 4   domain-complex-free (Product)  0.722042     55.97      40.00   93.16
# 7   domain-simple-force (Product)  0.838736     63.49      55.63   73.93
# 5    domain-simple-free (Product)  0.820097     63.96      51.57   84.19
# 2           general-complex-force  0.757699     57.35      43.04   85.90
# 0            general-complex-free  0.672609     51.79      35.93   92.74
# 3            general-simple-force  0.835494     59.96      55.68   64.96
# 1             general-simple-free  0.781199     58.84      45.73   82.48
# 8                 Narayan-complex  0.874392     67.78      65.99   69.66
# 9                  Narayan-simple  0.872771     65.65      67.26   64.10
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...

# %% [markdown]
# ## WDC

# %%
df_wdc_7b = pd.read_json("../results/baseline/wdc/2024-02-18_7b_all.json")
df_wdc_13b = pd.read_json("../results/baseline/wdc/2024-02-08 22:19:09.396702_13b_all.json")
df_wdc_70b = pd.read_json("../results/baseline/wdc/2024-02-18_70b_all.json")
df_wdc_turbo_0125 = pd.read_json("../results/baseline/wdc/2024-05-20-19-58-24_turbo_0125_wdc_all.json")

# drop tasks that are not in prompt_order
df_wdc_7b = df_wdc_7b[df_wdc_7b["task"].isin(prompt_order)]
df_wdc_13b = df_wdc_13b[df_wdc_13b["task"].isin(prompt_order)]
df_wdc_70b = df_wdc_70b[df_wdc_70b["task"].isin(prompt_order)]
df_wdc_turbo_0125 = df_wdc_turbo_0125[df_wdc_turbo_0125["task"].isin(prompt_order)]

# %%
analytics.draw_scores(df_wdc_7b, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.726392     44.33      37.60    54.0
# 4   domain-complex-free (Product)  0.748184     51.70      42.17    66.8
# 7   domain-simple-force (Product)  0.801453     13.38      55.88     7.6
# 5    domain-simple-free (Product)  0.794996      2.31      30.00     1.2
# 2           general-complex-force  0.579500     42.68      29.44    77.6
# 0            general-complex-free  0.468927     41.98      26.92    95.2
# 3            general-simple-force  0.800646      8.86      57.14     4.8
# 1             general-simple-free  0.786925      8.97      32.50     5.2
# 8                 Narayan-complex  0.811138     25.00      62.90    15.6
# 9                  Narayan-simple  0.824052     44.39      61.27    34.8
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...

# %%
analytics.draw_scores(df_wdc_13b, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.674738     54.36      37.91    96.0
# 4   domain-complex-free (Product)  0.834544     60.04      58.56    61.6
# 7   domain-simple-force (Product)  0.761098     53.16      43.98    67.2
# 5    domain-simple-free (Product)  0.801453      6.11      66.67     3.2
# 2           general-complex-force  0.716707     57.96      41.37    96.8
# 0            general-complex-free  0.815174     57.36      53.66    61.6
# 3            general-simple-force  0.659403     45.05      33.40    69.2
# 1             general-simple-free  0.801453     15.17      55.00     8.8
# 8                 Narayan-complex  0.816788     20.91      81.08    12.0
# 9                  Narayan-simple  0.802260     13.43      57.58     7.6
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...

# %%
analytics.draw_scores(df_wdc_70b, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.882970     73.20      68.04    79.2
# 4   domain-complex-free (Product)  0.836965     69.21      55.91    90.8
# 7   domain-simple-force (Product)  0.828087     28.76      87.76    17.2
# 5    domain-simple-free (Product)  0.850686     45.75      85.71    31.2
# 2           general-complex-force  0.877320     68.85      70.59    67.2
# 0            general-complex-free  0.820016     67.25      53.13    91.6
# 3            general-simple-force  0.843422     40.85      85.90    26.8
# 1             general-simple-free  0.862793     53.30      85.09    38.8
# 8                 Narayan-complex  0.870864     62.26      75.86    52.8
# 9                  Narayan-simple  0.867635     60.39      76.22    50.0
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...

# %%
analytics.draw_scores(df_wdc_turbo_0125, prompt_order)
# Out:
#                              Task  Accuracy  F1 Score  Precision  Recall  \
# 6  domain-complex-force (Product)  0.881356     75.54      64.67    90.8
# 4   domain-complex-free (Product)  0.843422     71.39      56.54    96.8
# 7   domain-simple-force (Product)  0.902341     73.75      80.57    68.0
# 5    domain-simple-free (Product)  0.907183     79.57      71.57    89.6
# 2           general-complex-force  0.899919     78.40      69.44    90.0
# 0            general-complex-free  0.819209     68.72      52.79    98.4
# 3            general-simple-force  0.907990     74.44      84.69    66.4
# 1             general-simple-free  0.911219     80.70      71.88    92.0
# 8                 Narayan-complex  0.919290     79.25      82.33    76.4
# 9                  Narayan-simple  0.916868     76.21      90.16    66.0
#
#    Num -1 Responses
# 6                 0
# 4                 0
# 7                 0
# 5                 0
# 2                 0
# 0                 0
# ...
